# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('2011-16 Starter.xlsx')
df
# Out:
#                 Player  Pk     Age    SOS    FG   FGA    FG%   2P   2PA  \
# 0         Kyrie Irving   1  19.096   8.31   7.3  13.7  0.529  4.9   8.6
# 1       Brandon Knight   8  19.208   8.91   6.4  15.1  0.423  3.8   8.3
# 2         Kemba Walker   9  21.051  10.44   8.2  19.2  0.428  6.2  13.3
# 3      Jimmer Fredette  10  22.123   5.76  10.5  23.1  0.452  6.7  13.7
# 4          Nolan Smith  21  22.338   8.31   8.3  18.0  0.458  6.4  12.9
# ..                 ...  ..     ...    ...   ...   ...    ...  ...   ...
# 230      Jahlil Okafor   3  19.197   9.87   9.8  14.7  0.664  9.8  14.7
# 231       Jakob Poeltl   9  20.257   8.79   8.3  12.9  0.646  8.3  12.9
# 232     Chinanu Onuaku  37  19.239   7.74   7.2  11.6  0.620  7.2  11.5
# 233      Diamond Stone  40  19.138   8.31   8.3  14.6  0.568  8.3  14.6
# 234  Stephen Zimmerman  41  19.292   3.17   6.0  12.6  0.477  5.7  11.6
#
#        2P%  ...  BLK%  TOV%   AST:TOV  Hght\n(inches)  Weight  RSCI Rank  \
# 0    0.569  ...   1.8  16.4  1.722222              75     193        3.0
# 1    0.461  ...   0.6  16.8  1.342857              75     195        5.0
# 2    0.471  ...   0.5   9.5  2.000000              73     184       16.0
# 3    0.491  ...   0.1  12.7  1.200000              74     195        NaN
# 4    0.501  ...   0.2  14.8  1.621622              74     190       19.0
# ..     ...  ...   ...   ...       ...             ...     ...        ...
# 230  0.664  ...   4.5  15.6  0.515152              83     260        2.0
# 231  0.646  ...   5.0  13.7  0.962963              84     248        NaN
# 232  0.623  ...   9.6  20.8  0.794118              82     245       63.0
# 233  0.568  ...   7.1  12.9  0.269231              83     255        6.0
# 234  0.492  ...   7.5  17.1  0.406250              84     240        9.0
#
#      Max Measured Wingspan (inches)  Avg Measured Wingspan (inches  \
# 0                             76.00                          75.67
# 1                             78.75                          78.38
# 2                             75.50                          74.50
# 3                             77.00                          76.75
# 4                             78.00                          77.88
# ..                              ...                            ...
# 230                           90.25                          89.06
# 231                           86.75                          85.88
# 232                           86.75                          86.63
# 233                           88.00                          86.89
# 234                           87.25                          86.80
#
#      Difference  Starter
# 0          1.00        0
# 1          3.75        0
# 2          2.50        0
# 3          3.00        0
# 4          4.00        0
# ..          ...      ...
# 230        7.25        0
# 231        2.75        0
# 232        4.75        0
# 233        5.00        0
# 234        3.25        0
#
# [235 rows x 45 columns]

# %%
import dabl

# %%
df['RSCI Rank'] = pd.to_numeric(df['RSCI Rank'], errors='coerce')
df['RSCI Rank'] = df['RSCI Rank'].fillna(df['RSCI Rank'].mean())

# %%
dabl.plot(df, target_col="Starter")
# Out:
# Target looks like classification
# Showing only top 10 of 43 continuous features
# /opt/anaconda3/lib/python3.7/site-packages/dabl/plot/utils.py:621: UserWarning: Dropped 1 outliers in column Age.
#   int(dropped), series.name), UserWarning)
# /opt/anaconda3/lib/python3.7/site-packages/dabl/plot/utils.py:621: UserWarning: Dropped 1 outliers in column RSCI Rank.
#   int(dropped), series.name), UserWarning)
# Linear Discriminant Analysis training set score: 0.686
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")

# %%
sc = dabl.SimpleClassifier()
sc.fit(df, target_col='Starter')
# Out:
# Running DummyClassifier(strategy='prior')
# accuracy: 0.749 average_precision: 0.251 roc_auc: 0.500 recall_macro: 0.500 f1_macro: 0.428
# === new best DummyClassifier(strategy='prior') (using recall_macro):
# accuracy: 0.749 average_precision: 0.251 roc_auc: 0.500 recall_macro: 0.500 f1_macro: 0.428
#
# Running GaussianNB()
# accuracy: 0.336 average_precision: 0.273 roc_auc: 0.551 recall_macro: 0.546 f1_macro: 0.319
# === new best GaussianNB() (using recall_macro):
# accuracy: 0.336 average_precision: 0.273 roc_auc: 0.551 recall_macro: 0.546 f1_macro: 0.319
#
# Running MultinomialNB()
# accuracy: 0.741 average_precision: 0.373 roc_auc: 0.619 recall_macro: 0.494 f1_macro: 0.425
# Running DecisionTreeClassifier(class_weight='balanced', max_depth=1)
# accuracy: 0.613 average_precision: 0.329 roc_auc: 0.640 recall_macro: 0.640 f1_macro: 0.580
# === new best DecisionTreeClassifier(class_weight='balanced', max_depth=1) (using recall_macro):
# accuracy: 0.613 average_precision: 0.329 roc_auc: 0.640 recall_macro: 0.640 f1_macro: 0.580
#
# Running DecisionTreeClassifier(class_weight='balanced', max_depth=5)
# accuracy: 0.676 average_precision: 0.374 roc_auc: 0.652 recall_macro: 0.665 f1_macro: 0.630
# === new best DecisionTreeClassifier(class_weight='balanced', max_depth=5) (using recall_macro):
# accuracy: 0.676 average_precision: 0.374 roc_auc: 0.652 recall_macro: 0.665 f1_macro: 0.630
#
# Running DecisionTreeClassifier(class_weight='balanced', min_impurity_decrease=0.01)
# accuracy: 0.711 average_precision: 0.370 roc_auc: 0.636 recall_macro: 0.665 f1_macro: 0.645
# === new best DecisionTreeClassifier(class_weight='balanced', min_impurity_decrease=0.01) (using recall_macro):
# accuracy: 0.711 average_precision: 0.370 roc_auc: 0.636 recall_macro: 0.665 f1_macro: 0.645
#
# Running LogisticRegression(C=0.1, class_weight='balanced', max_iter=1000, solver='lbfgs')
# accuracy: 0.644 average_precision: 0.420 roc_auc: 0.669 recall_macro: 0.639 f1_macro: 0.601
# Running LogisticRegression(class_weight='balanced', max_iter=1000, solver='lbfgs')
# accuracy: 0.669 average_precision: 0.405 roc_auc: 0.646 recall_macro: 0.650 f1_macro: 0.616
#
# Best model:
# DecisionTreeClassifier(class_weight='balanced', min_impurity_decrease=0.01)
# Best Scores:
# accuracy: 0.711 average_precision: 0.370 roc_auc: 0.636 recall_macro: 0.665 f1_macro: 0.645
# SimpleClassifier(random_state=None, refit=True, shuffle=True, type_hints=None,
#                  verbose=1)

# %%
X = df.drop(['Starter', 'Player'], axis=1)
y = df['Starter']

# %%
from xverse.transformer import MonotonicBinning

clf = MonotonicBinning()
clf.fit(X, y)
# Out:
# MonotonicBinning(cardinality_cutoff=5, custom_binning=None, feature_names='all',
#                  force_bins=4, max_bins=20, prefix=None)

# %%
clf.bins
# Out:
# {'Pk': array([ 1., 17., 34., 60.]),
#  'Age': array([18.242, 20.176, 22.024, 27.148]),
#  'SOS': array([-5.39,  7.17,  8.31, 12.13]),
#  'FG': array([ 3.5,  6.3,  7.4, 11.2]),
#  'FGA': array([ 7.6, 12.9, 15.5, 23.1]),
#  'FG%': array([0.369, 0.453, 0.5  , 0.664]),
#  '2P': array([ 2.2,  4.7,  6.1, 10.2]),
#  '2PA': array([ 4. ,  9.1, 11.5, 17.3]),
#  '2P%': array([0.376, 0.497, 0.541, 0.664]),
#  '3P': array([0. , 0.8, 2. , 4.6]),
#  '3PA': array([ 0. ,  2.2,  5.4, 11.2]),
#  '3P%': array([0.   , 0.304, 0.377, 0.6  ]),
#  'FT': array([1.1, 3.8, 5. , 8.7]),
#  'FTA': array([ 1.9,  5.1,  6.8, 11.6]),
#  'FT%': array([0.295, 0.706, 0.783, 0.925]),
#  'TRB': array([ 2.8,  6.1,  9.6, 16.7]),
#  'AST': array([ 0.2,  1.9,  3.4, 11.8]),
#  'STL': array([0.3, 1.1, 1.6, 3.5]),
#  'BLK': array([0. , 0.5, 1.2, 5.8]),
#  'TOV': array([1. , 2.3, 3. , 5. ]),
#  'PF': array([1.4, 2.5, 3.2, 7.6]),
#  'PTS': array([ 9.9, 17.8, 21.1, 32.3]),
#  'ORtg': array([ 95.5, 113.4, 119.2, 139. ]),
#  'DRtg': array([ 78.1,  93.1,  99.6, 112.2]),
#  'PER': array([11.9, 21.9, 25.9, 36.2]),
#  'TS%': array([0.485, 0.555, 0.59 , 0.697]),
#  'eFG%': array([0.438, 0.513, 0.552, 0.664]),
#  '3PAr': array([0.   , 0.178, 0.362, 0.666]),
#  'FTr': array([0.18 , 0.362, 0.462, 0.908]),
#  'ORB%': array([ 0.5,  3.8,  9. , 20. ]),
#  'DRB%': array([ 7. , 13.2, 19.2, 33. ]),
#  'TRB%': array([ 4.2,  9. , 14.1, 25.6]),
#  'AST%': array([ 0.9, 10.5, 18.4, 50. ]),
#  'STL%': array([0.4, 1.7, 2.3, 5. ]),
#  'BLK%': array([ 0.1,  1.4,  3.4, 13.7]),
#  'TOV%': array([ 5.7, 12. , 14.7, 27.8]),
#  'AST:TOV': array([0.05882353, 0.79411765, 1.375     , 3.61904762]),
#  'Hght\n(inches)': array([69., 78., 81., 85.]),
#  'Weight': array([160., 205., 230., 279.]),
#  'RSCI Rank': array([  1.        ,  24.        ,  45.59668508, 251.        ]),
#  'Max Measured Wingspan (inches)': array([71.  , 81.25, 84.5 , 90.25]),
#  'Avg Measured Wingspan (inches': array([70.88, 80.58, 84.  , 90.25]),
#  'Difference': array([-2.25,  3.  ,  4.5 ,  8.25])}

# %%
output_bins = clf.bins #will be used later in this exercise

# %%
out_X = clf.transform(X)

# %%
out_X.head()
# Out:
#               Pk               Age             SOS           FG           FGA  \
# 0  (0.999, 17.0]  (18.241, 20.176]    (7.17, 8.31]   (6.3, 7.4]  (12.9, 15.5]
# 1  (0.999, 17.0]  (18.241, 20.176]   (8.31, 12.13]   (6.3, 7.4]  (12.9, 15.5]
# 2  (0.999, 17.0]  (20.176, 22.024]   (8.31, 12.13]  (7.4, 11.2]  (15.5, 23.1]
# 3  (0.999, 17.0]  (22.024, 27.148]  (-5.391, 7.17]  (7.4, 11.2]  (15.5, 23.1]
# 4   (17.0, 34.0]  (22.024, 27.148]    (7.17, 8.31]  (7.4, 11.2]  (15.5, 23.1]
#
#               FG%                         2P           2PA             2P%  \
# 0    (0.5, 0.664]                 (4.7, 6.1]  (3.999, 9.1]  (0.541, 0.664]
# 1  (0.368, 0.453]  (2.1990000000000003, 4.7]  (3.999, 9.1]  (0.375, 0.497]
# 2  (0.368, 0.453]                (6.1, 10.2]  (11.5, 17.3]  (0.375, 0.497]
# 3  (0.368, 0.453]                (6.1, 10.2]  (11.5, 17.3]  (0.375, 0.497]
# 4    (0.453, 0.5]                (6.1, 10.2]  (11.5, 17.3]  (0.497, 0.541]
#
#            3P  ...          STL%          BLK%           TOV%         AST:TOV  \
# 0  (2.0, 4.6]  ...    (2.3, 5.0]    (1.4, 3.4]   (14.7, 27.8]  (1.375, 3.619]
# 1  (2.0, 4.6]  ...  (0.399, 1.7]  (0.099, 1.4]   (14.7, 27.8]  (0.794, 1.375]
# 2  (0.8, 2.0]  ...    (2.3, 5.0]  (0.099, 1.4]  (5.699, 12.0]  (1.375, 3.619]
# 3  (2.0, 4.6]  ...    (1.7, 2.3]  (0.099, 1.4]   (12.0, 14.7]  (0.794, 1.375]
# 4  (0.8, 2.0]  ...    (1.7, 2.3]  (0.099, 1.4]   (14.7, 27.8]  (1.375, 3.619]
#
#    Hght\n(inches)            Weight       RSCI Rank  \
# 0  (68.999, 78.0]  (159.999, 205.0]   (0.999, 24.0]
# 1  (68.999, 78.0]  (159.999, 205.0]   (0.999, 24.0]
# 2  (68.999, 78.0]  (159.999, 205.0]   (0.999, 24.0]
# 3  (68.999, 78.0]  (159.999, 205.0]  (24.0, 45.597]
# 4  (68.999, 78.0]  (159.999, 205.0]   (0.999, 24.0]
#
#   Max Measured Wingspan (inches) Avg Measured Wingspan (inches     Difference
# 0                (70.999, 81.25]    (70.87899999999999, 80.58]  (-2.251, 3.0]
# 1                (70.999, 81.25]    (70.87899999999999, 80.58]     (3.0, 4.5]
# 2                (70.999, 81.25]    (70.87899999999999, 80.58]  (-2.251, 3.0]
# 3                (70.999, 81.25]    (70.87899999999999, 80.58]  (-2.251, 3.0]
# 4                (70.999, 81.25]    (70.87899999999999, 80.58]     (3.0, 4.5]
#
# [5 rows x 43 columns]

# %%
from xverse.transformer import WOE

clf = WOE()
clf.fit(X, y)
# Out:
# WOE(exclude_features=None, feature_names='all', mono_cardinality_cutoff=5,
#     mono_custom_binning={'2P': array([ 2.2,  4.7,  6.1, 10.2]),
#                          '2P%': array([0.376, 0.497, 0.541, 0.664]),
#                          '2PA': array([ 4. ,  9.1, 11.5, 17.3]),
#                          '3P': array([0. , 0.8, 2. , 4.6]),
#                          '3P%': array([0.   , 0.304, 0.377, 0.6  ]),
#                          '3PA': array([ 0. ,  2.2,  5.4, 11.2]),
#                          '3PAr': array([0.   , 0.178, 0.362, 0.666]),
#                          'AST': array([ 0.2,  1.9,  3.4,...
#               'PER': {Interval(11.899000000000001, 21.9, closed='right'): -0.17556477433107484,
#                       Interval(21.9, 25.9, closed='right'): 0.14848494229158085,
#                       Interval(25.9, 36.2, closed='right'): 0.028235814140004017},
#               'PF': {Interval(1.399, 2.5, closed='right'): -0.2009744898564432,
#                      Interval(2.5, 3.2, closed='right'): 0.22390870410882274,
#                      Interval(3.2, 7.6, closed='right'): -0.08570844520921385}, ...},
#     woe_prefix=None)

# %%
clf.woe_df.head(10)
# Out:
#   Variable_Name                   Category  Count  Event  Non_Event  \
# 0            2P  (2.1990000000000003, 4.7]     79     21         58
# 1            2P                 (4.7, 6.1]     78     19         59
# 2            2P                (6.1, 10.2]     78     19         59
# 3           2P%             (0.375, 0.497]     80     19         61
# 4           2P%             (0.497, 0.541]     77     21         56
# 5           2P%             (0.541, 0.664]     78     19         59
# 6           2PA               (3.999, 9.1]     81     22         59
# 7           2PA                (9.1, 11.5]     78     17         61
# 8           2PA               (11.5, 17.3]     76     20         56
# 9            3P              (-0.001, 0.8]     82     16         66
#
#    Event_Rate  Non_Event_Rate  Event_Distribution  Non_Event_Distribution  \
# 0    0.265823        0.734177            0.355932                0.329545
# 1    0.243590        0.756410            0.322034                0.335227
# 2    0.243590        0.756410            0.322034                0.335227
# 3    0.237500        0.762500            0.322034                0.346591
# 4    0.272727        0.727273            0.355932                0.318182
# 5    0.243590        0.756410            0.322034                0.335227
# 6    0.271605        0.728395            0.372881                0.335227
# 7    0.217949        0.782051            0.288136                0.346591
# 8    0.263158        0.736842            0.338983                0.318182
# 9    0.195122        0.804878            0.271186                0.375000
#
#         WOE  Information_Value
# 0  0.077026           0.003092
# 1 -0.040152           0.003092
# 2 -0.040152           0.003092
# 3 -0.073488           0.006567
# 4  0.112117           0.006567
# 5 -0.040152           0.006567
# 6  0.106452           0.016123
# 7 -0.184714           0.016123
# 8  0.063327           0.016123
# 9 -0.324119           0.061885

# %%
clf.iv_df
# Out:
#                      Variable_Name  Information_Value
# 31                              Pk           0.712463
# 26                            ORB%           0.252297
# 10                             Age           0.230094
# 11   Avg Measured Wingspan (inches           0.192467
# 25  Max Measured Wingspan (inches)           0.184226
# 34                             STL           0.151268
# 35                            STL%           0.137600
# 32                       RSCI Rank           0.136918
# 38                             TRB           0.126816
# 24                  Hght\n(inches)           0.122981
# 12                             BLK           0.107528
# 13                            BLK%           0.106064
# 33                             SOS           0.083317
# 40                             TS%           0.079041
# 41                          Weight           0.075742
# 7                              AST           0.074064
# 15                            DRtg           0.062933
# 3                               3P           0.061885
# 21                             FT%           0.061537
# 42                            eFG%           0.058589
# 5                              3PA           0.045082
# 39                            TRB%           0.043551
# 27                            ORtg           0.036030
# 29                              PF           0.034765
# 16                      Difference           0.030999
# 8                             AST%           0.030518
# 14                            DRB%           0.024516
# 4                              3P%           0.022685
# 28                             PER           0.017839
# 2                              2PA           0.016123
# 37                            TOV%           0.015858
# 23                             FTr           0.013705
# 30                             PTS           0.013598
# 6                             3PAr           0.013372
# 20                              FT           0.013254
# 1                              2P%           0.006567
# 22                             FTA           0.005752
# 9                          AST:TOV           0.004347
# 0                               2P           0.003092
# 36                             TOV           0.002415
# 17                              FG           0.002326
# 19                             FGA           0.002016
# 18                             FG%           0.001608

# %%
output_woe_bins = clf.woe_bins #future transformation

# %%
output_woe_bins
# Out:
# {'2P': {Interval(2.1990000000000003, 4.7, closed='right'): 0.07702597830943604,
#   Interval(4.7, 6.1, closed='right'): -0.040151913606846626,
#   Interval(6.1, 10.2, closed='right'): -0.040151913606846626},
#  '2P%': {Interval(0.375, 0.497, closed='right'): -0.07348833387443861,
#   Interval(0.497, 0.541, closed='right'): 0.112117298120706,
#   Interval(0.541, 0.664, closed='right'): -0.040151913606846626},
#  '2PA': {Interval(3.999, 9.1, closed='right'): 0.10645156058502879,
#   Interval(9.1, 11.5, closed='right'): -0.18471396898466294,
#   Interval(11.5, 17.3, closed='right'): 0.06332713395127411},
#  '3P': {Interval(-0.001, 0.8, closed='right'): -0.324119468654212,
#   Interval(0.8, 2.0, closed='right'): 0.2820163349161036,
#   Interval(2.0, 4.6, closed='right'): 0.012033839563723463},
#  '3P%': {Interval(-0.001, 0.304, closed='right'): 0.2030890763264329,
#   Interval(0.304, 0.377, closed='right'): -0.12755555514471423,
#   Interval(0.377, 0.6, closed='right'): -0.09421913487712236},
#  '3PA': {Interval(-0.001, 2.2, closed='right'): -0.2775994530193192,
#   Interval(2.2, 5.4, closed='right'): 0.010334603810763753,
#   Interval(5.4, 11.2, closed='right'): 0.25216337176642234},
#  '3PAr': {Interval(-0.001, 0.178, closed='right'): -0.15981641736293564,
#   Interval(0.178, 0.362, closed='right'): 0.112117298120706,
#   Interval(0.362, 0.666, closed='right'): 0.045627556851873224},
#  'AST': {Interval(0.199, 1.9, closed='right'): -0.30885199652342354,
#   Interval(1.9, 3.4, closed='right'): 0.34153046244851126,
#   Interval(3.4, 11.8, closed='right'): -0.0771247015178222},
#  'AST%': {Interval(0.899, 10.5, closed='right'): -0.2009744898564432,
#   Interval(10.5, 18.4, closed='right'): 0.22110758182911117,
#   Interval(18.4, 50.0, closed='right'): -0.040151913606846626},
#  'AST:TOV': {Interval(0.0578, 0.794, closed='right'): 0.059931544950135855,
#   Interval(0.794, 1.375, closed='right'): -0.09421913487712236,
#   Interval(1.375, 3.619, closed='right'): 0.028235814140004017},
#  'Age': {Interval(18.241, 20.176, closed='right'): 0.49332542858331047,
#   Interval(20.176, 22.024, closed='right'): 0.028235814140004017,
#   Interval(22.024, 27.148, closed='right'): -0.7138507954601632},
#  'Avg Measured Wingspan (inches': {Interval(70.87899999999999, 80.58, closed='right'): -0.12755555514471423,
#   Interval(80.58, 84.0, closed='right'): 0.5089986625374789,
#   Interval(84.0, 90.25, closed='right'): -0.5652815254711},
#  'BLK': {Interval(-0.001, 0.5, closed='right'): -0.23272318817102344,
#   Interval(0.5, 1.2, closed='right'): 0.4390200837257682,
#   Interval(1.2, 5.8, closed='right'): -0.261599111672878},
#  'BLK%': {Interval(0.099, 1.4, closed='right'): -0.21697483120288433,
#   Interval(1.4, 3.4, closed='right'): 0.4184915035846396,
#   Interval(3.4, 13.7, closed='right'): -0.2933478099874583},
#  'DRB%': {Interval(6.999, 13.2, closed='right'): -0.21697483120288433,
#   Interval(13.2, 19.2, closed='right'): 0.045627556851873224,
#   Interval(19.2, 33.0, closed='right'): 0.15863731375559897},
#  'DRtg': {Interval(78.09899999999999, 93.1, closed='right'): 0.3228383294363587,
#   Interval(93.1, 99.6, closed='right'): -0.261599111672878,
#   Interval(99.6, 112.2, closed='right'): -0.11102625319350355},
#  'Difference': {Interval(-2.251, 3.0, closed='right'): 0.03878602503515645,
#   Interval(3.0, 4.5, closed='right'): 0.1968585265757968,
#   Interval(4.5, 8.25, closed='right'): -0.24533859080109777},
#  'FG': {Interval(3.499, 6.3, closed='right'): -0.05695903192322787,
#   Interval(6.3, 7.4, closed='right'): 0.059931544950135855,
#   Interval(7.4, 11.2, closed='right'): -0.00566573753567742},
#  'FG%': {Interval(0.368, 0.453, closed='right'): -0.05695903192322787,
#   Interval(0.453, 0.5, closed='right'): 0.028235814140004017,
#   Interval(0.5, 0.664, closed='right'): 0.028235814140004017},
#  'FGA': {Interval(7.598999999999999, 12.9, closed='right'): -0.02219503948688809,
#   Interval(12.9, 15.5, closed='right'): 0.06332713395127411,
#   Interval(15.5, 23.1, closed='right'): -0.040151913606846626},
#  'FT': {Interval(1.0990000000000002, 3.8, closed='right'): 0.05685461944565651,
#   Interval(3.8, 5.0, closed='right'): 0.09969477812214893,
#   Interval(5.0, 8.7, closed='right'): -0.1681846670334522},
#  'FT%': {Interval(0.294, 0.706, closed='right'): 0.3228383294363587,
#   Interval(0.706, 0.783, closed='right'): -0.12755555514471423,
#   Interval(0.783, 0.925, closed='right'): -0.24533859080109777},
#  'FTA': {Interval(1.899, 5.1, closed='right'): -0.08974885474621892,
#   Interval(5.1, 6.8, closed='right'): 0.09441772102130513,
#   Interval(6.8, 11.6, closed='right'): -0.00566573753567742},
#  'FTr': {Interval(0.179, 0.362, closed='right'): 0.14093773665619808,
#   Interval(0.362, 0.462, closed='right'): -0.14381607601649457,
#   Interval(0.462, 0.908, closed='right'): -0.00566573753567742},
#  'Hght\n(inches)': {Interval(68.999, 78.0, closed='right'): -0.1903998407350159,
#   Interval(78.0, 81.0, closed='right'): 0.483180979511538,
#   Interval(81.0, 85.0, closed='right'): -0.3593057777792556},
#  'Max Measured Wingspan (inches)': {Interval(70.999, 81.25, closed='right'): -0.22137431036236901,
#   Interval(81.25, 84.5, closed='right'): 0.5284167483945805,
#   Interval(84.5, 90.25, closed='right'): -0.4825898096259866},
#  'ORB%': {Interval(0.499, 3.8, closed='right'): -0.7286658812453038,
#   Interval(3.8, 9.0, closed='right'): 0.5284167483945805,
#   Interval(9.0, 20.0, closed='right'): -0.00566573753567742},
#  'ORtg': {Interval(95.499, 113.4, closed='right'): 0.2030890763264329,
#   Interval(113.4, 119.2, closed='right'): -0.261599111672878,
#   Interval(119.2, 139.0, closed='right'): 0.028235814140004017},
#  'PER': {Interval(11.899000000000001, 21.9, closed='right'): -0.17556477433107484,
#   Interval(21.9, 25.9, closed='right'): 0.14848494229158085,
#   Interval(25.9, 36.2, closed='right'): 0.028235814140004017},
#  'PF': {Interval(1.399, 2.5, closed='right'): -0.2009744898564432,
#   Interval(2.5, 3.2, closed='right'): 0.22390870410882274,
#   Interval(3.2, 7.6, closed='right'): -0.08570844520921385},
#  'PTS': {Interval(9.899000000000001, 17.8, closed='right'): -0.10574919609266008,
#   Interval(17.8, 21.1, closed='right'): -0.05973295880595308,
#   Interval(21.1, 32.3, closed='right'): 0.15863731375559897},
#  'Pk': {Interval(0.999, 17.0, closed='right'): 0.8752230672875618,
#   Interval(17.0, 34.0, closed='right'): -0.2775994530193192,
#   Interval(34.0, 60.0, closed='right'): -1.3199865990304787},
#  'RSCI Rank': {Interval(0.999, 24.0, closed='right'): 0.39979937057248705,
#   Interval(24.0, 45.597, closed='right'): -0.05011750010651117,
#   Interval(45.597, 251.0, closed='right'): -0.574760269425644},
#  'SOS': {Interval(-5.391, 7.17, closed='right'): -0.2933478099874583,
#   Interval(7.17, 8.31, closed='right'): -0.12755555514471423,
#   Interval(8.31, 12.13, closed='right'): 0.3799967432763072},
#  'STL': {Interval(0.299, 1.1, closed='right'): -0.5905993334553898,
#   Interval(1.1, 1.6, closed='right'): 0.22794911364582784,
#   Interval(1.6, 3.5, closed='right'): 0.29216870638012166},
#  'STL%': {Interval(0.399, 1.7, closed='right'): -0.5446622382683645,
#   Interval(1.7, 2.3, closed='right'): 0.2719659990626021,
#   Interval(2.3, 5.0, closed='right'): 0.2394567204973076},
#  'TOV': {Interval(0.999, 2.3, closed='right'): -0.00566573753567742,
#   Interval(2.3, 3.0, closed='right'): 0.05685461944565651,
#   Interval(3.0, 5.0, closed='right'): -0.06629035935211228},
#  'TOV%': {Interval(5.699, 12.0, closed='right'): 0.07702597830943604,
#   Interval(12.0, 14.7, closed='right'): 0.09441772102130513,
#   Interval(14.7, 27.8, closed='right'): -0.18471396898466294},
#  'TRB': {Interval(2.799, 6.1, closed='right'): -0.4576508612787345,
#   Interval(6.1, 9.6, closed='right'): 0.4192174564295886,
#   Interval(9.6, 16.7, closed='right'): -0.040151913606846626},
#  'TRB%': {Interval(4.199, 9.0, closed='right'): -0.23272318817102344,
#   Interval(9.0, 14.1, closed='right'): 0.26366719624790713,
#   Interval(14.1, 25.6, closed='right'): -0.05973295880595308},
#  'TS%': {Interval(0.484, 0.555, closed='right'): 0.059931544950135855,
#   Interval(0.555, 0.59, closed='right'): 0.2820163349161036,
#   Interval(0.59, 0.697, closed='right'): -0.41113084564384167},
#  'Weight': {Interval(159.999, 205.0, closed='right'): -0.21697483120288433,
#   Interval(205.0, 230.0, closed='right'): 0.34573214930221124,
#   Interval(230.0, 279.0, closed='right'): -0.22435493850050683},
#  'eFG%': {Interval(0.437, 0.513, closed='right'): -0.2482273747069887,
#   Interval(0.513, 0.552, closed='right'): 0.31975666289895055,
#   Interval(0.552, 0.664, closed='right'): -0.09421913487712236}}

# %%
output_mono_bins = clf.mono_custom_binning  #future transformation

# %%
output_mono_bins
# Out:
# {'Pk': array([ 1., 17., 34., 60.]),
#  'Age': array([18.242, 20.176, 22.024, 27.148]),
#  'SOS': array([-5.39,  7.17,  8.31, 12.13]),
#  'FG': array([ 3.5,  6.3,  7.4, 11.2]),
#  'FGA': array([ 7.6, 12.9, 15.5, 23.1]),
#  'FG%': array([0.369, 0.453, 0.5  , 0.664]),
#  '2P': array([ 2.2,  4.7,  6.1, 10.2]),
#  '2PA': array([ 4. ,  9.1, 11.5, 17.3]),
#  '2P%': array([0.376, 0.497, 0.541, 0.664]),
#  '3P': array([0. , 0.8, 2. , 4.6]),
#  '3PA': array([ 0. ,  2.2,  5.4, 11.2]),
#  '3P%': array([0.   , 0.304, 0.377, 0.6  ]),
#  'FT': array([1.1, 3.8, 5. , 8.7]),
#  'FTA': array([ 1.9,  5.1,  6.8, 11.6]),
#  'FT%': array([0.295, 0.706, 0.783, 0.925]),
#  'TRB': array([ 2.8,  6.1,  9.6, 16.7]),
#  'AST': array([ 0.2,  1.9,  3.4, 11.8]),
#  'STL': array([0.3, 1.1, 1.6, 3.5]),
#  'BLK': array([0. , 0.5, 1.2, 5.8]),
#  'TOV': array([1. , 2.3, 3. , 5. ]),
#  'PF': array([1.4, 2.5, 3.2, 7.6]),
#  'PTS': array([ 9.9, 17.8, 21.1, 32.3]),
#  'ORtg': array([ 95.5, 113.4, 119.2, 139. ]),
#  'DRtg': array([ 78.1,  93.1,  99.6, 112.2]),
#  'PER': array([11.9, 21.9, 25.9, 36.2]),
#  'TS%': array([0.485, 0.555, 0.59 , 0.697]),
#  'eFG%': array([0.438, 0.513, 0.552, 0.664]),
#  '3PAr': array([0.   , 0.178, 0.362, 0.666]),
#  'FTr': array([0.18 , 0.362, 0.462, 0.908]),
#  'ORB%': array([ 0.5,  3.8,  9. , 20. ]),
#  'DRB%': array([ 7. , 13.2, 19.2, 33. ]),
#  'TRB%': array([ 4.2,  9. , 14.1, 25.6]),
#  'AST%': array([ 0.9, 10.5, 18.4, 50. ]),
#  'STL%': array([0.4, 1.7, 2.3, 5. ]),
#  'BLK%': array([ 0.1,  1.4,  3.4, 13.7]),
#  'TOV%': array([ 5.7, 12. , 14.7, 27.8]),
#  'AST:TOV': array([0.05882353, 0.79411765, 1.375     , 3.61904762]),
#  'Hght\n(inches)': array([69., 78., 81., 85.]),
#  'Weight': array([160., 205., 230., 279.]),
#  'RSCI Rank': array([  1.        ,  24.        ,  45.59668508, 251.        ]),
#  'Max Measured Wingspan (inches)': array([71.  , 81.25, 84.5 , 90.25]),
#  'Avg Measured Wingspan (inches': array([70.88, 80.58, 84.  , 90.25]),
#  'Difference': array([-2.25,  3.  ,  4.5 ,  8.25])}

# %%
clf.transform(X).head()
# Out:
#          Pk       Age       SOS        FG       FGA       FG%        2P  \
# 0  0.875223  0.493325 -0.127556  0.059932  0.063327  0.028236 -0.040152
# 1  0.875223  0.493325  0.379997  0.059932  0.063327 -0.056959  0.077026
# 2  0.875223  0.028236  0.379997 -0.005666 -0.040152 -0.056959 -0.040152
# 3  0.875223 -0.713851 -0.293348 -0.005666 -0.040152 -0.056959 -0.040152
# 4 -0.277599 -0.713851 -0.127556 -0.005666 -0.040152  0.028236 -0.040152
#
#         2PA       2P%        3P  ...      STL%      BLK%      TOV%   AST:TOV  \
# 0  0.106452 -0.040152  0.012034  ...  0.239457  0.418492 -0.184714  0.028236
# 1  0.106452 -0.073488  0.012034  ... -0.544662 -0.216975 -0.184714 -0.094219
# 2  0.063327 -0.073488  0.282016  ...  0.239457 -0.216975  0.077026  0.028236
# 3  0.063327 -0.073488  0.012034  ...  0.271966 -0.216975  0.094418 -0.094219
# 4  0.063327  0.112117  0.282016  ...  0.271966 -0.216975 -0.184714  0.028236
#
#    Hght\n(inches)    Weight  RSCI Rank  Max Measured Wingspan (inches)  \
# 0         -0.1904 -0.216975   0.399799                       -0.221374
# 1         -0.1904 -0.216975   0.399799                       -0.221374
# 2         -0.1904 -0.216975   0.399799                       -0.221374
# 3         -0.1904 -0.216975  -0.050118                       -0.221374
# 4         -0.1904 -0.216975   0.399799                       -0.221374
#
#    Avg Measured Wingspan (inches  Difference
# 0                      -0.127556    0.038786
# 1                      -0.127556    0.196859
# 2                      -0.127556    0.038786
# 3                      -0.127556    0.038786
# 4                      -0.127556    0.196859
#
# [5 rows x 43 columns]

# %%
from xverse.graph import BarCharts

# %%
woe_df = clf.woe_df

# %%
clf = BarCharts(bar_type='v')

# %%
clf.plot(woe_df)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:338: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /opt/anaconda3/lib/python3.7/site-packages/xverse/graph/_bivariate_charts.py:152: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
# BarCharts(bar_color='#058caa', bar_type='v', exclude_features=None,
#           feature_names='all', fig_size=(8, 6), num_color='#ed8549',
#           plot_metric='mean')

# %%
from xverse.ensemble import VotingSelector

clf = VotingSelector()
clf.fit(X, y)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# VotingSelector(exclude_features=None, feature_names='all',
#                handle_category='woe', minimum_votes=0, no_of_features=21,
#                numerical_missing_values='median',
#                selection_techniques=['WOE', 'RF', 'RFE', 'ETC', 'CS', 'L_ONE'])

# %%
clf.available_techniques
# Out:
# ['WOE', 'RF', 'RFE', 'ETC', 'CS', 'L_ONE']

# %%
clf.feature_importances_
# Out:
#                      Variable_Name  Information_Value  Random_Forest  \
# 0                               Pk           0.712463       0.080110
# 1                             ORB%           0.252297       0.022945
# 2                              Age           0.230094       0.027044
# 3    Avg Measured Wingspan (inches           0.192467       0.047137
# 4   Max Measured Wingspan (inches)           0.184226       0.007157
# 5                              STL           0.151268       0.020132
# 6                             STL%           0.137600       0.018235
# 7                        RSCI Rank           0.136918       0.025401
# 8                              TRB           0.126816       0.028062
# 9                   Hght\n(inches)           0.122981       0.002147
# 10                             BLK           0.107528       0.007873
# 11                            BLK%           0.106064       0.011281
# 12                             SOS           0.083317       0.056734
# 13                             TS%           0.079041       0.027197
# 14                          Weight           0.075742       0.021535
# 15                             AST           0.074064       0.030757
# 16                            DRtg           0.062933       0.026435
# 17                              3P           0.061885       0.018481
# 18                             FT%           0.061537       0.022569
# 19                            eFG%           0.058589       0.020469
# 20                             3PA           0.045082       0.006948
# 21                            TRB%           0.043551       0.033642
# 22                            ORtg           0.036030       0.020646
# 23                              PF           0.034765       0.020482
# 24                      Difference           0.030999       0.011932
# 25                            AST%           0.030518       0.021466
# 26                            DRB%           0.024516       0.019832
# 27                             3P%           0.022685       0.027833
# 28                             PER           0.017839       0.012660
# 29                             2PA           0.016123       0.015239
# 30                            TOV%           0.015858       0.013403
# 31                             FTr           0.013705       0.020989
# 32                             PTS           0.013598       0.015636
# 33                            3PAr           0.013372       0.002365
# 34                              FT           0.013254       0.043357
# 35                             2P%           0.006567       0.041333
# 36                             FTA           0.005752       0.007711
# 37                         AST:TOV           0.004347       0.061324
# 38                              2P           0.003092       0.017985
# 39                             TOV           0.002415       0.007813
# 40                              FG           0.002326       0.012722
# 41                             FGA           0.002016       0.020527
# 42                             FG%           0.001608       0.022457
#
#     Recursive_Feature_Elimination  Extra_Trees  Chi_Square     L_One
# 0                        0.000000     0.092353    4.919869 -0.018455
# 1                        0.000000     0.022152    0.096715  0.000000
# 2                       -0.526936     0.037742    0.893458  0.000000
# 3                       -0.180349     0.024929    0.002949  0.000000
# 4                        0.000000     0.038061    0.009945  0.000000
# 5                        0.388047     0.022772    0.639405  0.000000
# 6                        0.221598     0.025923    0.621484  0.000000
# 7                        0.000000     0.017545    0.442768 -0.000420
# 8                       -0.190037     0.016522    0.085915  0.000000
# 9                        0.290898     0.034702    0.087133  0.003063
# 10                      -0.253857     0.019551    0.025878  0.000000
# 11                       0.083826     0.018163    0.020416  0.000000
# 12                       0.000000     0.036847    0.044420  0.000000
# 13                       0.000000     0.018528    0.040979  0.000000
# 14                       0.000000     0.020390    0.000011 -0.001145
# 15                      -0.482701     0.022029    0.015949  0.000000
# 16                       0.000000     0.021940    0.069305  0.000000
# 17                       0.287407     0.010326    0.042875  0.000000
# 18                      -0.352418     0.022489    0.144336  0.000000
# 19                       0.000000     0.023438    0.002314  0.000000
# 20                      -0.075033     0.013306    0.032862  0.000000
# 21                       0.194858     0.026303    0.092458  0.000000
# 22                       0.000000     0.014879    0.023180  0.000000
# 23                      -0.288274     0.027315    0.000353  0.000000
# 24                       0.000000     0.026678    0.079024  0.000000
# 25                       0.099692     0.025713    0.004807  0.000000
# 26                       0.000000     0.019694    0.085917  0.000000
# 27                       0.000000     0.029682    0.003009  0.000000
# 28                       0.000000     0.020809    0.011807  0.000000
# 29                       0.013472     0.012061    0.000102  0.000000
# 30                       0.000000     0.012207    0.010277  0.000000
# 31                       0.000000     0.020505    0.011639  0.000000
# 32                       0.126530     0.020130    0.003304  0.000000
# 33                       0.000000     0.022644    0.027421  0.000000
# 34                      -0.796968     0.020249    0.010215  0.000000
# 35                       0.000000     0.015510    0.000329  0.000000
# 36                       0.531929     0.014830    0.020017  0.000000
# 37                       0.000000     0.025082    0.019175  0.000000
# 38                      -0.319274     0.018765    0.000939  0.000000
# 39                       0.000000     0.029058    0.000224  0.000000
# 40                       0.031430     0.010850    0.005508  0.000000
# 41                       0.000000     0.012772    0.013206  0.000000
# 42                       0.000000     0.014557    0.002642  0.000000

# %%
clf.feature_votes_
# Out:
#                      Variable_Name  Information_Value  Random_Forest  \
# 2                              Age                  1              1
# 18                             FT%                  1              1
# 0                               Pk                  1              1
# 15                             AST                  1              1
# 3    Avg Measured Wingspan (inches                  1              1
# 1                             ORB%                  1              1
# 5                              STL                  1              0
# 6                             STL%                  1              0
# 8                              TRB                  1              1
# 9                   Hght\n(inches)                  1              0
# 12                             SOS                  1              1
# 16                            DRtg                  1              1
# 20                             3PA                  1              0
# 17                              3P                  1              0
# 21                            TRB%                  0              1
# 11                            BLK%                  1              0
# 10                             BLK                  1              0
# 13                             TS%                  1              1
# 7                        RSCI Rank                  1              1
# 14                          Weight                  1              1
# 4   Max Measured Wingspan (inches)                  1              0
# 25                            AST%                  0              1
# 19                            eFG%                  1              0
# 22                            ORtg                  0              1
# 23                              PF                  0              0
# 24                      Difference                  0              0
# 27                             3P%                  0              1
# 37                         AST:TOV                  0              1
# 33                            3PAr                  0              0
# 34                              FT                  0              1
# 35                             2P%                  0              1
# 40                              FG                  0              0
# 39                             TOV                  0              0
# 38                              2P                  0              0
# 36                             FTA                  0              0
# 29                             2PA                  0              0
# 32                             PTS                  0              0
# 31                             FTr                  0              1
# 26                            DRB%                  0              0
# 42                             FG%                  0              1
# 30                            TOV%                  0              0
# 28                             PER                  0              0
# 41                             FGA                  0              0
#
#     Recursive_Feature_Elimination  Extra_Trees  Chi_Square  L_One  Votes
# 2                               1            1           1      1      6
# 18                              1            1           1      1      6
# 0                               0            1           1      1      5
# 15                              1            1           0      1      5
# 3                               1            1           0      1      5
# 1                               0            1           1      1      5
# 5                               1            1           1      1      5
# 6                               1            1           1      1      5
# 8                               1            0           1      1      5
# 9                               1            1           1      1      5
# 12                              0            1           1      1      5
# 16                              0            1           1      1      5
# 20                              1            0           1      1      4
# 17                              1            0           1      1      4
# 21                              1            1           1      0      4
# 11                              1            0           1      1      4
# 10                              1            0           1      1      4
# 13                              0            0           1      1      4
# 7                               0            0           1      1      4
# 14                              0            0           0      1      3
# 4                               0            1           0      1      3
# 25                              1            1           0      0      3
# 19                              0            1           0      1      3
# 22                              0            0           1      0      2
# 23                              1            1           0      0      2
# 24                              0            1           1      0      2
# 27                              0            1           0      0      2
# 37                              0            1           0      0      2
# 33                              0            1           1      0      2
# 34                              1            0           0      0      2
# 35                              0            0           0      0      1
# 40                              1            0           0      0      1
# 39                              0            1           0      0      1
# 38                              1            0           0      0      1
# 36                              1            0           0      0      1
# 29                              1            0           0      0      1
# 32                              1            0           0      0      1
# 31                              0            0           0      0      1
# 26                              0            0           1      0      1
# 42                              0            0           0      0      1
# 30                              0            0           0      0      0
# 28                              0            0           0      0      0
# 41                              0            0           0      0      0

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
list(df.columns)
# Out:
# ['Player',
#  'Pk',
#  'Age',
#  'SOS',
#  'FG',
#  'FGA',
#  'FG%',
#  '2P',
#  '2PA',
#  '2P%',
#  '3P',
#  '3PA',
#  '3P%',
#  'FT',
#  'FTA',
#  'FT%',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS',
#  'ORtg',
#  'DRtg',
#  'PER',
#  'TS%',
#  'eFG%',
#  '3PAr',
#  'FTr',
#  'ORB%',
#  'DRB%',
#  'TRB%',
#  'AST%',
#  'STL%',
#  'BLK%',
#  'TOV%',
#  'AST:TOV',
#  'Hght\n(inches)',
#  'Weight',
#  'RSCI Rank',
#  'Max Measured Wingspan (inches)',
#  'Avg Measured Wingspan (inches',
#  'Difference',
#  'Starter']

# %%
features = ['SOS','FG','FGA','FG%', '2P','2PA','2P%','3P','3P%','FT','FTA','FT%','TRB','AST',
'STL','BLK','TOV','PF','PTS','ORtg','PER','TS%','eFG%','3PAr','FTr', 'ORB%','DRB%','TRB%','AST%',
 'BLK%','TOV%','AST:TOV','Hght\n(inches)','Weight','RSCI Rank', 'Max Measured Wingspan (inches)',
'Avg Measured Wingspan (inches', 'Difference']

# %%
import seaborn as sns

# %%
sns.pairplot(df[['Age','FT%','STL%','Pk','DRtg','TRB', '3PA', 'Starter']], hue='Starter',kind="scatter",plot_kws=dict(s=80, edgecolor="white", linewidth=2.5))

# %%
import numpy as np

from sklearn.model_selection import StratifiedKFold
from yellowbrick.model_selection import LearningCurve

# Create the learning curve visualizer
cv = StratifiedKFold(n_splits=12)
sizes = np.linspace(0.3, 1.0, 10)

# Instantiate the classification model and visualizer
model = LogisticRegression(solver='liblinear', random_state=2)
visualizer = LearningCurve(
    model, cv=cv, scoring='roc_auc', train_sizes=sizes, n_jobs=4
)

visualizer.fit(X, y)        # Fit the data to the visualizer
visualizer.show()           # Finalize and render the figure
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/yellowbrick/base.py:246: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
from sklearn.model_selection import StratifiedKFold
from yellowbrick.model_selection import CVScores

# Create a cross-validation strategy
cv = StratifiedKFold(n_splits=12, random_state=42)

# Instantiate the classification model and visualizer
model = LogisticRegression(solver='liblinear', random_state=2)
visualizer = CVScores(model, cv=cv, scoring='roc_auc')

visualizer.fit(X, y)        # Fit the data to the visualizer
visualizer.show()           # Finalize and render the figure
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/yellowbrick/base.py:246: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
X = df.drop(['SOS','FG','FGA','FG%','2P','2PA','2P%','3P','3PA','3P%','FT','FTA','TRB', 'PER','Player',
 'STL','BLK','TOV','PF','PTS','ORtg','DRtg','TS%','eFG%','3PAr','Starter', 'FTr','DRB%', 'TRB%',
 'AST%','BLK%','TOV%','AST:TOV','Hght\n(inches)', 'Weight','RSCI Rank', 'Max Measured Wingspan (inches)',
 'Avg Measured Wingspan (inches','Difference'], axis=1)
y = df['Starter']

# %%
X
# Out:
#      Pk     Age    FT%  AST  ORB%  STL%
# 0     1  19.096  0.901  6.2   2.3   3.0
# 1     8  19.208  0.795  4.7   2.2   1.1
# 2     9  21.051  0.819  4.8   3.9   3.1
# 3    10  22.123  0.894  4.8   2.0   2.1
# 4    21  22.338  0.813  6.0   4.1   2.0
# ..   ..     ...    ...  ...   ...   ...
# 230   3  19.197  0.510  1.7  14.8   1.5
# 231   9  20.257  0.689  2.6  11.9   1.1
# 232  37  19.239  0.589  2.7  13.7   1.9
# 233  40  19.138  0.761  0.7  12.4   1.3
# 234  41  19.292  0.624  1.3   8.8   1.1
#
# [235 rows x 6 columns]

# %%
import numpy as np

from sklearn.model_selection import StratifiedKFold
from yellowbrick.model_selection import LearningCurve

# Create the learning curve visualizer
cv = StratifiedKFold(n_splits=12)
sizes = np.linspace(0.3, 1.0, 10)

# Instantiate the classification model and visualizer
model = LogisticRegression(solver='liblinear', random_state=2)
visualizer = LearningCurve(
    model, cv=cv, scoring='roc_auc', train_sizes=sizes, n_jobs=4
)

visualizer.fit(X, y)        # Fit the data to the visualizer
visualizer.show()           # Finalize and render the figure
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/yellowbrick/base.py:246: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
from sklearn.model_selection import StratifiedKFold
from yellowbrick.model_selection import CVScores

# Create a cross-validation strategy
cv = StratifiedKFold(n_splits=12, random_state=42)

# Instantiate the classification model and visualizer
model = LogisticRegression(solver='liblinear', random_state=2)
visualizer = CVScores(model, cv=cv, scoring='roc_auc')

visualizer.fit(X, y)        # Fit the data to the visualizer
visualizer.show()           # Finalize and render the figure
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/yellowbrick/base.py:246: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
X
# Out:
#      Pk     Age    FT%  AST  ORB%  STL%
# 0     1  19.096  0.901  6.2   2.3   3.0
# 1     8  19.208  0.795  4.7   2.2   1.1
# 2     9  21.051  0.819  4.8   3.9   3.1
# 3    10  22.123  0.894  4.8   2.0   2.1
# 4    21  22.338  0.813  6.0   4.1   2.0
# ..   ..     ...    ...  ...   ...   ...
# 230   3  19.197  0.510  1.7  14.8   1.5
# 231   9  20.257  0.689  2.6  11.9   1.1
# 232  37  19.239  0.589  2.7  13.7   1.9
# 233  40  19.138  0.761  0.7  12.4   1.3
# 234  41  19.292  0.624  1.3   8.8   1.1
#
# [235 rows x 6 columns]

# %%
features = ['Pk', 'Age', 'FT%','AST','ORB%','STL%']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
logreg = LogisticRegression(solver='liblinear', random_state=2).fit(x_train, y_train)
y_scores_logreg = logreg.predict_proba(x_test)[:,1]
y_pred_logreg = logreg.predict(x_test)

print("Train accuracy:",logreg.score(x_train, y_train))
print("Test accuracy:", logreg.score(x_test, y_test))
print("ROC AUC:", roc_auc_score(y_test, y_scores_logreg))

ax = pd.DataFrame(
    logreg.coef_.transpose(),
    index=features,
    columns=['coefficients']
).sort_values('coefficients').plot(
    kind='barh', legend=False, title='Logistic Regression Feature Coefficients', figsize=(10,5), fontsize=14
)

ax.title.set_size(16)
# Out:
# Train accuracy: 0.7670454545454546
# Test accuracy: 0.7288135593220338
# ROC AUC: 0.7848837209302326

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

# %%
xg_cl = xgb.XGBClassifier()

# %%
params = {"max_depth": [10,30,50],
              "min_child_weight" : [1,3,6],
              "n_estimators": [200],
              "learning_rate": [0.05, 0.1,0.16],}

# %%
grid_search = GridSearchCV(xg_cl, params, cv = 3, verbose=10, n_jobs=-1)

# %%
grid_search.fit(X_train, Y_train)
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1979s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1084s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done  66 out of  81 | elapsed:    2.9s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  75 out of  81 | elapsed:    2.9s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  81 out of  81 | elapsed:    2.9s finished
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      colsample_bylevel=1, colsample_bynode=1,
#                                      colsample_bytree=1, gamma=0,
#                                      learning_rate=0.1, max_delta_step=0,
#                                      max_depth=3, min_child_weight=1,
#                                      missing=None, n_estimators=100, n_jobs=1,
#                                      nthread=None, objective='binary:logistic',
#                                      random_state=0, reg_alpha=0, reg_lambda=1,
#                                      scale_pos_weight=1, seed=None, silent=None,
#                                      subsample=1, verbosity=1),
#              iid='warn', n_jobs=-1,
#              param_grid={'learning_rate': [0.05, 0.1, 0.16],
#                          'max_depth': [10, 30, 50],
#                          'min_child_weight': [1, 3, 6], 'n_estimators': [200]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=10)

# %%
grid_search.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.05, max_delta_step=0, max_depth=10,
#               min_child_weight=6, missing=None, n_estimators=200, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score

# %%
xg = xgb.XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=1, gamma=0,
              learning_rate=0.05, max_delta_step=0, max_depth=10,
              min_child_weight=6, missing=None, n_estimators=200, n_jobs=1,
              nthread=None, objective='binary:logistic', random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
              silent=None, subsample=1, verbosity=1).fit(X_train, Y_train)
y_scores_xg = xg.predict_proba(X_test)[:,1]

print("Train Accuracy:",xg.score(X_train, Y_train))
print("Test Accuracy:", xg.score(X_test, Y_test))
print("ROC AUC:", roc_auc_score(Y_test, y_scores_xg))
# Out:
# Train Accuracy: 0.8579545454545454
# Test Accuracy: 0.711864406779661
# ROC AUC: 0.7223837209302325

# %%
xg_roc_auc = roc_auc_score(Y_test, y_scores_xg)
fpr, tpr, thresholds = metrics.roc_curve(Y_test, y_scores_xg)
plt.plot(fpr, tpr, label='XGBoost (AUC = %0.2f)' % xg_roc_auc)
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Random Model', alpha=.8)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   if sys.path[0] == '':

# %%
import shap

# %%
explainer = shap.TreeExplainer(xg)

# %%
shap_values = explainer.shap_values(X_train)

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...

# %%
shap.summary_plot(shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/summary.py:464: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
shap.summary_plot(shap_values, X_train, plot_type="bar")

# %%
shap.dependence_plot('Pk', shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/dependence.py:291: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
shap.dependence_plot("AST", shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/dependence.py:291: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
shap.dependence_plot("ORB%", shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/dependence.py:291: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
shap.dependence_plot("FT%", shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/dependence.py:291: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
shap.dependence_plot("Age", shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/dependence.py:291: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
shap.dependence_plot("STL%", shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/dependence.py:291: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()
