# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('2011-16 Bust.xlsx')
df
# Out:
#                 Player  Pk     Age    SOS    FG   FGA    FG%   2P   2PA  \
# 0         Kyrie Irving   1  19.096   8.31   7.3  13.7  0.529  4.9   8.6
# 1       Brandon Knight   8  19.208   8.91   6.4  15.1  0.423  3.8   8.3
# 2         Kemba Walker   9  21.051  10.44   8.2  19.2  0.428  6.2  13.3
# 3      Jimmer Fredette  10  22.123   5.76  10.5  23.1  0.452  6.7  13.7
# 4          Nolan Smith  21  22.338   8.31   8.3  18.0  0.458  6.4  12.9
# ..                 ...  ..     ...    ...   ...   ...    ...  ...   ...
# 230      Jahlil Okafor   3  19.197   9.87   9.8  14.7  0.664  9.8  14.7
# 231       Jakob Poeltl   9  20.257   8.79   8.3  12.9  0.646  8.3  12.9
# 232     Chinanu Onuaku  37  19.239   7.74   7.2  11.6  0.620  7.2  11.5
# 233      Diamond Stone  40  19.138   8.31   8.3  14.6  0.568  8.3  14.6
# 234  Stephen Zimmerman  41  19.292   3.17   6.0  12.6  0.477  5.7  11.6
#
#        2P%  ...  BLK%  TOV%   AST:TOV  Hght\n(inches)  Weight  RSCI Rank  \
# 0    0.569  ...   1.8  16.4  1.722222              75     193        3.0
# 1    0.461  ...   0.6  16.8  1.342857              75     195        5.0
# 2    0.471  ...   0.5   9.5  2.000000              73     184       16.0
# 3    0.491  ...   0.1  12.7  1.200000              74     195        NaN
# 4    0.501  ...   0.2  14.8  1.621622              74     190       19.0
# ..     ...  ...   ...   ...       ...             ...     ...        ...
# 230  0.664  ...   4.5  15.6  0.515152              83     260        2.0
# 231  0.646  ...   5.0  13.7  0.962963              84     248        NaN
# 232  0.623  ...   9.6  20.8  0.794118              82     245       63.0
# 233  0.568  ...   7.1  12.9  0.269231              83     255        6.0
# 234  0.492  ...   7.5  17.1  0.406250              84     240        9.0
#
#      Max Measured Wingspan (inches)  Avg Measured Wingspan (inches  \
# 0                             76.00                          75.67
# 1                             78.75                          78.38
# 2                             75.50                          74.50
# 3                             77.00                          76.75
# 4                             78.00                          77.88
# ..                              ...                            ...
# 230                           90.25                          89.06
# 231                           86.75                          85.88
# 232                           86.75                          86.63
# 233                           88.00                          86.89
# 234                           87.25                          86.80
#
#      Difference  Bust
# 0          1.00     0
# 1          3.75     0
# 2          2.50     0
# 3          3.00     1
# 4          4.00     1
# ..          ...   ...
# 230        7.25     0
# 231        2.75     0
# 232        4.75     1
# 233        5.00     1
# 234        3.25     1
#
# [235 rows x 45 columns]

# %%
import dabl

# %%
df['RSCI Rank'] = pd.to_numeric(df['RSCI Rank'], errors='coerce')
df['RSCI Rank'] = df['RSCI Rank'].fillna(df['RSCI Rank'].mean())

# %%
dabl.plot(df, target_col="Bust")
# Out:
# Target looks like classification
# Showing only top 10 of 43 continuous features
# /opt/anaconda3/lib/python3.7/site-packages/dabl/plot/utils.py:621: UserWarning: Dropped 1 outliers in column Age.
#   int(dropped), series.name), UserWarning)
# Linear Discriminant Analysis training set score: 0.802
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")

# %%
sc = dabl.SimpleClassifier()
sc.fit(df, target_col='Bust')
# Out:
# Running DummyClassifier(strategy='prior')
# accuracy: 0.630 average_precision: 0.370 roc_auc: 0.500 recall_macro: 0.500 f1_macro: 0.386
# === new best DummyClassifier(strategy='prior') (using recall_macro):
# accuracy: 0.630 average_precision: 0.370 roc_auc: 0.500 recall_macro: 0.500 f1_macro: 0.386
#
# Running GaussianNB()
# accuracy: 0.452 average_precision: 0.452 roc_auc: 0.535 recall_macro: 0.486 f1_macro: 0.354
# Running MultinomialNB()
# accuracy: 0.617 average_precision: 0.488 roc_auc: 0.576 recall_macro: 0.542 f1_macro: 0.525
# === new best MultinomialNB() (using recall_macro):
# accuracy: 0.617 average_precision: 0.488 roc_auc: 0.576 recall_macro: 0.542 f1_macro: 0.525
#
# Running DecisionTreeClassifier(class_weight='balanced', max_depth=1)
# accuracy: 0.672 average_precision: 0.507 roc_auc: 0.691 recall_macro: 0.691 f1_macro: 0.664
# === new best DecisionTreeClassifier(class_weight='balanced', max_depth=1) (using recall_macro):
# accuracy: 0.672 average_precision: 0.507 roc_auc: 0.691 recall_macro: 0.691 f1_macro: 0.664
#
# Running DecisionTreeClassifier(class_weight='balanced', max_depth=5)
# accuracy: 0.574 average_precision: 0.415 roc_auc: 0.562 recall_macro: 0.553 f1_macro: 0.548
# Running DecisionTreeClassifier(class_weight='balanced', min_impurity_decrease=0.01)
# accuracy: 0.544 average_precision: 0.400 roc_auc: 0.499 recall_macro: 0.512 f1_macro: 0.510
# Running LogisticRegression(C=0.1, class_weight='balanced', max_iter=1000, solver='lbfgs')
# accuracy: 0.693 average_precision: 0.610 roc_auc: 0.717 recall_macro: 0.683 f1_macro: 0.678
# Running LogisticRegression(class_weight='balanced', max_iter=1000, solver='lbfgs')
# accuracy: 0.698 average_precision: 0.590 roc_auc: 0.711 recall_macro: 0.694 f1_macro: 0.685
# === new best LogisticRegression(class_weight='balanced', max_iter=1000, solver='lbfgs') (using recall_macro):
# accuracy: 0.698 average_precision: 0.590 roc_auc: 0.711 recall_macro: 0.694 f1_macro: 0.685
#
#
# Best model:
# LogisticRegression(class_weight='balanced', max_iter=1000, solver='lbfgs')
# Best Scores:
# accuracy: 0.698 average_precision: 0.590 roc_auc: 0.711 recall_macro: 0.694 f1_macro: 0.685
# SimpleClassifier(random_state=None, refit=True, shuffle=True, type_hints=None,
#                  verbose=1)

# %%
X = df.drop(['Bust', 'Player'], axis=1)
y = df['Bust']

# %%
from xverse.transformer import MonotonicBinning

clf = MonotonicBinning()
clf.fit(X, y)
# Out:
# MonotonicBinning(cardinality_cutoff=5, custom_binning=None, feature_names='all',
#                  force_bins=4, max_bins=20, prefix=None)

# %%
clf.bins
# Out:
# {'Pk': array([ 1., 17., 34., 60.]),
#  'Age': array([18.242, 20.176, 22.024, 27.148]),
#  'SOS': array([-5.39,  7.17,  8.31, 12.13]),
#  'FG': array([ 3.5,  6.3,  7.4, 11.2]),
#  'FGA': array([ 7.6, 12.9, 15.5, 23.1]),
#  'FG%': array([0.369, 0.453, 0.5  , 0.664]),
#  '2P': array([ 2.2,  4.7,  6.1, 10.2]),
#  '2PA': array([ 4. ,  9.1, 11.5, 17.3]),
#  '2P%': array([0.376, 0.497, 0.541, 0.664]),
#  '3P': array([0. , 0.8, 2. , 4.6]),
#  '3PA': array([ 0. ,  2.2,  5.4, 11.2]),
#  '3P%': array([0.   , 0.304, 0.377, 0.6  ]),
#  'FT': array([1.1, 3.8, 5. , 8.7]),
#  'FTA': array([ 1.9,  5.1,  6.8, 11.6]),
#  'FT%': array([0.295, 0.706, 0.783, 0.925]),
#  'TRB': array([ 2.8,  6.1,  9.6, 16.7]),
#  'AST': array([ 0.2,  1.9,  3.4, 11.8]),
#  'STL': array([0.3, 1.1, 1.6, 3.5]),
#  'BLK': array([0. , 0.5, 1.2, 5.8]),
#  'TOV': array([1. , 2.3, 3. , 5. ]),
#  'PF': array([1.4, 2.5, 3.2, 7.6]),
#  'PTS': array([ 9.9, 17.8, 21.1, 32.3]),
#  'ORtg': array([ 95.5, 113.4, 119.2, 139. ]),
#  'DRtg': array([ 78.1,  93.1,  99.6, 112.2]),
#  'PER': array([11.9, 21.9, 25.9, 36.2]),
#  'TS%': array([0.485, 0.555, 0.59 , 0.697]),
#  'eFG%': array([0.438, 0.513, 0.552, 0.664]),
#  '3PAr': array([0.   , 0.178, 0.362, 0.666]),
#  'FTr': array([0.18 , 0.362, 0.462, 0.908]),
#  'ORB%': array([ 0.5,  3.8,  9. , 20. ]),
#  'DRB%': array([ 7. , 13.2, 19.2, 33. ]),
#  'TRB%': array([ 4.2,  9. , 14.1, 25.6]),
#  'AST%': array([ 0.9, 10.5, 18.4, 50. ]),
#  'STL%': array([0.4, 1.7, 2.3, 5. ]),
#  'BLK%': array([ 0.1,  1.4,  3.4, 13.7]),
#  'TOV%': array([ 5.7, 12. , 14.7, 27.8]),
#  'AST:TOV': array([0.05882353, 0.79411765, 1.375     , 3.61904762]),
#  'Hght\n(inches)': array([69., 78., 81., 85.]),
#  'Weight': array([160., 205., 230., 279.]),
#  'RSCI Rank': array([  1.        ,  24.        ,  45.59668508, 251.        ]),
#  'Max Measured Wingspan (inches)': array([71.  , 81.25, 84.5 , 90.25]),
#  'Avg Measured Wingspan (inches': array([70.88, 80.58, 84.  , 90.25]),
#  'Difference': array([-2.25,  3.  ,  4.5 ,  8.25])}

# %%
output_bins = clf.bins #will be used later in this exercise

# %%
out_X = clf.transform(X)

# %%
out_X.head()
# Out:
#               Pk               Age             SOS           FG           FGA  \
# 0  (0.999, 17.0]  (18.241, 20.176]    (7.17, 8.31]   (6.3, 7.4]  (12.9, 15.5]
# 1  (0.999, 17.0]  (18.241, 20.176]   (8.31, 12.13]   (6.3, 7.4]  (12.9, 15.5]
# 2  (0.999, 17.0]  (20.176, 22.024]   (8.31, 12.13]  (7.4, 11.2]  (15.5, 23.1]
# 3  (0.999, 17.0]  (22.024, 27.148]  (-5.391, 7.17]  (7.4, 11.2]  (15.5, 23.1]
# 4   (17.0, 34.0]  (22.024, 27.148]    (7.17, 8.31]  (7.4, 11.2]  (15.5, 23.1]
#
#               FG%                         2P           2PA             2P%  \
# 0    (0.5, 0.664]                 (4.7, 6.1]  (3.999, 9.1]  (0.541, 0.664]
# 1  (0.368, 0.453]  (2.1990000000000003, 4.7]  (3.999, 9.1]  (0.375, 0.497]
# 2  (0.368, 0.453]                (6.1, 10.2]  (11.5, 17.3]  (0.375, 0.497]
# 3  (0.368, 0.453]                (6.1, 10.2]  (11.5, 17.3]  (0.375, 0.497]
# 4    (0.453, 0.5]                (6.1, 10.2]  (11.5, 17.3]  (0.497, 0.541]
#
#            3P  ...          STL%          BLK%           TOV%         AST:TOV  \
# 0  (2.0, 4.6]  ...    (2.3, 5.0]    (1.4, 3.4]   (14.7, 27.8]  (1.375, 3.619]
# 1  (2.0, 4.6]  ...  (0.399, 1.7]  (0.099, 1.4]   (14.7, 27.8]  (0.794, 1.375]
# 2  (0.8, 2.0]  ...    (2.3, 5.0]  (0.099, 1.4]  (5.699, 12.0]  (1.375, 3.619]
# 3  (2.0, 4.6]  ...    (1.7, 2.3]  (0.099, 1.4]   (12.0, 14.7]  (0.794, 1.375]
# 4  (0.8, 2.0]  ...    (1.7, 2.3]  (0.099, 1.4]   (14.7, 27.8]  (1.375, 3.619]
#
#    Hght\n(inches)            Weight       RSCI Rank  \
# 0  (68.999, 78.0]  (159.999, 205.0]   (0.999, 24.0]
# 1  (68.999, 78.0]  (159.999, 205.0]   (0.999, 24.0]
# 2  (68.999, 78.0]  (159.999, 205.0]   (0.999, 24.0]
# 3  (68.999, 78.0]  (159.999, 205.0]  (24.0, 45.597]
# 4  (68.999, 78.0]  (159.999, 205.0]   (0.999, 24.0]
#
#   Max Measured Wingspan (inches) Avg Measured Wingspan (inches     Difference
# 0                (70.999, 81.25]    (70.87899999999999, 80.58]  (-2.251, 3.0]
# 1                (70.999, 81.25]    (70.87899999999999, 80.58]     (3.0, 4.5]
# 2                (70.999, 81.25]    (70.87899999999999, 80.58]  (-2.251, 3.0]
# 3                (70.999, 81.25]    (70.87899999999999, 80.58]  (-2.251, 3.0]
# 4                (70.999, 81.25]    (70.87899999999999, 80.58]     (3.0, 4.5]
#
# [5 rows x 43 columns]

# %%
from xverse.transformer import WOE

clf = WOE()
clf.fit(X, y)
# Out:
# WOE(exclude_features=None, feature_names='all', mono_cardinality_cutoff=5,
#     mono_custom_binning={'2P': array([ 2.2,  4.7,  6.1, 10.2]),
#                          '2P%': array([0.376, 0.497, 0.541, 0.664]),
#                          '2PA': array([ 4. ,  9.1, 11.5, 17.3]),
#                          '3P': array([0. , 0.8, 2. , 4.6]),
#                          '3P%': array([0.   , 0.304, 0.377, 0.6  ]),
#                          '3PA': array([ 0. ,  2.2,  5.4, 11.2]),
#                          '3PAr': array([0.   , 0.178, 0.362, 0.666]),
#                          'AST': array([ 0.2,  1.9,  3.4,...
#               'PER': {Interval(11.899000000000001, 21.9, closed='right'): 0.033465726870351896,
#                       Interval(21.9, 25.9, closed='right'): 0.18110172567641641,
#                       Interval(25.9, 36.2, closed='right'): -0.22011193357438988},
#               'PF': {Interval(1.399, 2.5, closed='right'): -0.013423020332140661,
#                      Interval(2.5, 3.2, closed='right'): -0.07775990823987253,
#                      Interval(3.2, 7.6, closed='right'): 0.11356895440955274}, ...},
#     woe_prefix=None)

# %%
clf.woe_df.head(10)
# Out:
#   Variable_Name                   Category  Count  Event  Non_Event  \
# 0            2P  (2.1990000000000003, 4.7]     79     32         47
# 1            2P                 (4.7, 6.1]     78     26         52
# 2            2P                (6.1, 10.2]     78     29         49
# 3           2P%             (0.375, 0.497]     80     35         45
# 4           2P%             (0.497, 0.541]     77     29         48
# 5           2P%             (0.541, 0.664]     78     23         55
# 6           2PA               (3.999, 9.1]     81     28         53
# 7           2PA                (9.1, 11.5]     78     32         46
# 8           2PA               (11.5, 17.3]     76     27         49
# 9            3P              (-0.001, 0.8]     82     32         50
#
#    Event_Rate  Non_Event_Rate  Event_Distribution  Non_Event_Distribution  \
# 0    0.405063        0.594937            0.367816                0.317568
# 1    0.333333        0.666667            0.298851                0.351351
# 2    0.371795        0.628205            0.333333                0.331081
# 3    0.437500        0.562500            0.402299                0.304054
# 4    0.376623        0.623377            0.333333                0.324324
# 5    0.294872        0.705128            0.264368                0.371622
# 6    0.345679        0.654321            0.321839                0.358108
# 7    0.410256        0.589744            0.367816                0.310811
# 8    0.355263        0.644737            0.310345                0.331081
# 9    0.390244        0.609756            0.367816                0.337838
#
#         WOE  Information_Value
# 0  0.146892           0.015893
# 1 -0.161843           0.015893
# 2  0.006780           0.015893
# 3  0.279990           0.064278
# 4  0.027399           0.064278
# 5 -0.340535           0.064278
# 6 -0.106783           0.014814
# 7  0.168399           0.014814
# 8 -0.064679           0.014814
# 9  0.085017           0.023253

# %%
clf.iv_df
# Out:
#                      Variable_Name  Information_Value
# 31                              Pk           0.894739
# 10                             Age           0.213868
# 38                             TRB           0.170763
# 34                             STL           0.161579
# 14                            DRB%           0.158666
# 26                            ORB%           0.140723
# 23                             FTr           0.133697
# 15                            DRtg           0.124035
# 35                            STL%           0.120378
# 11   Avg Measured Wingspan (inches           0.098820
# 39                            TRB%           0.096325
# 13                            BLK%           0.093542
# 18                             FG%           0.072058
# 4                              3P%           0.071163
# 1                              2P%           0.064278
# 42                            eFG%           0.063945
# 24                  Hght\n(inches)           0.062306
# 20                              FT           0.062123
# 32                       RSCI Rank           0.060642
# 7                              AST           0.055255
# 30                             PTS           0.052774
# 16                      Difference           0.047847
# 9                          AST:TOV           0.047810
# 41                          Weight           0.045496
# 12                             BLK           0.044904
# 33                             SOS           0.042430
# 40                             TS%           0.038102
# 37                            TOV%           0.036731
# 25  Max Measured Wingspan (inches)           0.034232
# 17                              FG           0.032971
# 19                             FGA           0.026808
# 28                             PER           0.026655
# 22                             FTA           0.024455
# 3                               3P           0.023253
# 21                             FT%           0.022918
# 5                              3PA           0.020041
# 8                             AST%           0.015893
# 0                               2P           0.015893
# 2                              2PA           0.014814
# 6                             3PAr           0.009501
# 27                            ORtg           0.006793
# 29                              PF           0.006085
# 36                             TOV           0.001930

# %%
output_woe_bins = clf.woe_bins #future transformation

# %%
output_woe_bins
# Out:
# {'2P': {Interval(2.1990000000000003, 4.7, closed='right'): 0.14689245619919938,
#   Interval(4.7, 6.1, closed='right'): -0.16184302545041387,
#   Interval(6.1, 10.2, closed='right'): 0.006779686985378769},
#  '2P%': {Interval(0.375, 0.497, closed='right'): 0.2799897268286253,
#   Interval(0.497, 0.541, closed='right'): 0.027398974188114347,
#   Interval(0.541, 0.664, closed='right'): -0.3405348141937898},
#  '2PA': {Interval(3.999, 9.1, closed='right'): -0.10678324826738665,
#   Interval(9.1, 11.5, closed='right'): 0.16839866142016288,
#   Interval(11.5, 17.3, closed='right'): -0.06467927699676612},
#  '3P': {Interval(-0.001, 0.8, closed='right'): 0.0850170524811119,
#   Interval(0.8, 2.0, closed='right'): -0.22011193357438988,
#   Interval(2.0, 4.6, closed='right'): 0.12583904700136697},
#  '3P%': {Interval(-0.001, 0.304, closed='right'): -0.35855331969646825,
#   Interval(0.304, 0.377, closed='right'): 0.0406812386610602,
#   Interval(0.377, 0.6, closed='right'): 0.2964645640321304},
#  '3PA': {Interval(-0.001, 2.2, closed='right'): -0.013423020332140661,
#   Interval(2.2, 5.4, closed='right'): 0.16584438161506612,
#   Interval(5.4, 11.2, closed='right'): -0.1824623126531496},
#  '3PAr': {Interval(-0.001, 0.178, closed='right'): -0.052643733485422145,
#   Interval(0.178, 0.362, closed='right'): 0.13664996310558256,
#   Interval(0.362, 0.666, closed='right'): -0.08488198431428552},
#  'AST': {Interval(0.199, 1.9, closed='right'): 0.20751707801563424,
#   Interval(1.9, 3.4, closed='right'): -0.3405348141937898,
#   Interval(3.4, 11.8, closed='right'): 0.10386014028259184},
#  'AST%': {Interval(0.899, 10.5, closed='right'): 0.14689245619919938,
#   Interval(10.5, 18.4, closed='right'): -0.16184302545041387,
#   Interval(18.4, 50.0, closed='right'): 0.006779686985378769},
#  'AST:TOV': {Interval(0.0578, 0.794, closed='right'): 0.177664114865953,
#   Interval(0.794, 1.375, closed='right'): -0.32218567552559324,
#   Interval(1.375, 3.619, closed='right'): 0.11514375788461918},
#  'Age': {Interval(18.241, 20.176, closed='right'): -0.6186014279461288,
#   Interval(20.176, 22.024, closed='right'): 0.006779686985378769,
#   Interval(22.024, 27.148, closed='right'): 0.5313041551095314},
#  'Avg Measured Wingspan (inches': {Interval(70.87899999999999, 80.58, closed='right'): 0.251002189955373,
#   Interval(80.58, 84.0, closed='right'): -0.4551908354378721,
#   Interval(84.0, 90.25, closed='right'): 0.18110172567641641},
#  'BLK': {Interval(-0.001, 0.5, closed='right'): 0.20751707801563424,
#   Interval(0.5, 1.2, closed='right'): -0.30349354251344074,
#   Interval(1.2, 5.8, closed='right'): 0.06130052586379588},
#  'BLK%': {Interval(0.099, 1.4, closed='right'): 0.2799897268286253,
#   Interval(1.4, 3.4, closed='right'): -0.438096402078572,
#   Interval(3.4, 13.7, closed='right'): 0.12583904700136697},
#  'DRB%': {Interval(6.999, 13.2, closed='right'): 0.5313041551095313,
#   Interval(13.2, 19.2, closed='right'): -0.26093392809464483,
#   Interval(19.2, 33.0, closed='right'): -0.3405348141937898},
#  'DRtg': {Interval(78.09899999999999, 93.1, closed='right'): -0.2979751997749939,
#   Interval(93.1, 99.6, closed='right'): -0.22011193357438988,
#   Interval(99.6, 112.2, closed='right'): 0.48001086072198085},
#  'Difference': {Interval(-2.251, 3.0, closed='right'): -0.0951516509517417,
#   Interval(3.0, 4.5, closed='right'): -0.22780099324221126,
#   Interval(4.5, 8.25, closed='right'): 0.2964645640321304},
#  'FG': {Interval(3.499, 6.3, closed='right'): 0.09409034868678672,
#   Interval(6.3, 7.4, closed='right'): -0.2571532052547389,
#   Interval(7.4, 11.2, closed='right'): 0.15862886982435784},
#  'FG%': {Interval(0.368, 0.453, closed='right'): 0.3536229778720791,
#   Interval(0.453, 0.5, closed='right'): -0.1046846116104653,
#   Interval(0.5, 0.664, closed='right'): -0.27962606110679744},
#  'FGA': {Interval(7.598999999999999, 12.9, closed='right'): -0.16184302545041387,
#   Interval(12.9, 15.5, closed='right'): -0.06467927699676612,
#   Interval(15.5, 23.1, closed='right'): 0.22114922680569182},
#  'FT': {Interval(1.0990000000000002, 3.8, closed='right'): -0.005000553957444274,
#   Interval(3.8, 5.0, closed='right'): -0.3288971101135801,
#   Interval(5.0, 8.7, closed='right'): 0.2964645640321304},
#  'FT%': {Interval(0.294, 0.706, closed='right'): -0.013423020332140661,
#   Interval(0.706, 0.783, closed='right'): -0.18089122042110833,
#   Interval(0.783, 0.925, closed='right'): 0.19037756813893814},
#  'FTA': {Interval(1.899, 5.1, closed='right'): -0.052643733485422145,
#   Interval(5.1, 6.8, closed='right'): -0.16184302545041387,
#   Interval(6.8, 11.6, closed='right'): 0.21285042399099668},
#  'FTr': {Interval(0.179, 0.362, closed='right'): -0.35855331969646825,
#   Interval(0.362, 0.462, closed='right'): 0.48129373453486995,
#   Interval(0.462, 0.908, closed='right'): -0.18164565274659372},
#  'Hght\n(inches)': {Interval(68.999, 78.0, closed='right'): 0.26560098937652565,
#   Interval(78.0, 81.0, closed='right'): -0.2694736896427793,
#   Interval(81.0, 85.0, closed='right'): -0.1878185118536745},
#  'Max Measured Wingspan (inches)': {Interval(70.999, 81.25, closed='right'): 0.17462921117079896,
#   Interval(81.25, 84.5, closed='right'): -0.2571532052547389,
#   Interval(84.5, 90.25, closed='right'): 0.06594090542029814},
#  'ORB%': {Interval(0.499, 3.8, closed='right'): 0.5059863471252414,
#   Interval(3.8, 9.0, closed='right'): -0.3159937052776723,
#   Interval(9.0, 20.0, closed='right'): -0.2418857331239504},
#  'ORtg': {Interval(95.499, 113.4, closed='right'): -0.06831696743959048,
#   Interval(113.4, 119.2, closed='right'): 0.11514375788461918,
#   Interval(119.2, 139.0, closed='right'): -0.04851434014341078},
#  'PER': {Interval(11.899000000000001, 21.9, closed='right'): 0.033465726870351896,
#   Interval(21.9, 25.9, closed='right'): 0.18110172567641641,
#   Interval(25.9, 36.2, closed='right'): -0.22011193357438988},
#  'PF': {Interval(1.399, 2.5, closed='right'): -0.013423020332140661,
#   Interval(2.5, 3.2, closed='right'): -0.07775990823987253,
#   Interval(3.2, 7.6, closed='right'): 0.11356895440955274},
#  'PTS': {Interval(9.899000000000001, 17.8, closed='right'): 0.13599141846538487,
#   Interval(17.8, 21.1, closed='right'): -0.34794530508427457,
#   Interval(21.1, 32.3, closed='right'): 0.16839866142016288},
#  'Pk': {Interval(0.999, 17.0, closed='right'): -1.3474666911081534,
#   Interval(17.0, 34.0, closed='right'): -0.013423020332140661,
#   Interval(34.0, 60.0, closed='right'): 1.123355218798108},
#  'RSCI Rank': {Interval(0.999, 24.0, closed='right'): -0.3336932823770733,
#   Interval(24.0, 45.597, closed='right'): 0.24362208265775032,
#   Interval(45.597, 251.0, closed='right'): 0.0457963393278306},
#  'SOS': {Interval(-5.391, 7.17, closed='right'): 0.177664114865953,
#   Interval(7.17, 8.31, closed='right'): 0.09409034868678672,
#   Interval(8.31, 12.13, closed='right'): -0.30349354251344074},
#  'STL': {Interval(0.299, 1.1, closed='right'): 0.45898349352990536,
#   Interval(1.1, 1.6, closed='right'): -0.052643733485422145,
#   Interval(1.6, 3.5, closed='right'): -0.5486160005464259},
#  'STL%': {Interval(0.399, 1.7, closed='right'): 0.39154221273437273,
#   Interval(1.7, 2.3, closed='right'): -0.039240703358081525,
#   Interval(2.3, 5.0, closed='right'): -0.44952509790219497},
#  'TOV': {Interval(0.999, 2.3, closed='right'): -0.05648250979258761,
#   Interval(2.3, 3.0, closed='right'): 0.04579633932783039,
#   Interval(3.0, 5.0, closed='right'): 0.012510361694363736},
#  'TOV%': {Interval(5.699, 12.0, closed='right'): 0.14689245619919938,
#   Interval(12.0, 14.7, closed='right'): -0.27962606110679744,
#   Interval(14.7, 27.8, closed='right'): 0.11514375788461918},
#  'TRB': {Interval(2.799, 6.1, closed='right'): 0.5313041551095313,
#   Interval(6.1, 9.6, closed='right'): -0.44952509790219497,
#   Interval(9.6, 16.7, closed='right'): -0.16184302545041387},
#  'TRB%': {Interval(4.199, 9.0, closed='right'): 0.4076901991423549,
#   Interval(9.0, 14.1, closed='right'): -0.2979751997749939,
#   Interval(14.1, 25.6, closed='right'): -0.161843025450414},
#  'TS%': {Interval(0.484, 0.555, closed='right'): 0.177664114865953,
#   Interval(0.555, 0.59, closed='right'): -0.27962606110679744,
#   Interval(0.59, 0.697, closed='right'): 0.0823539350616282},
#  'Weight': {Interval(159.999, 205.0, closed='right'): 0.2799897268286253,
#   Interval(205.0, 230.0, closed='right'): -0.21591024672068976,
#   Interval(230.0, 279.0, closed='right'): -0.07846141651136299},
#  'eFG%': {Interval(0.437, 0.513, closed='right'): 0.335559577983436,
#   Interval(0.513, 0.552, closed='right'): -0.18164565274659372,
#   Interval(0.552, 0.664, closed='right'): -0.20106373860369536}}

# %%
output_mono_bins = clf.mono_custom_binning  #future transformation

# %%
output_mono_bins
# Out:
# {'Pk': array([ 1., 17., 34., 60.]),
#  'Age': array([18.242, 20.176, 22.024, 27.148]),
#  'SOS': array([-5.39,  7.17,  8.31, 12.13]),
#  'FG': array([ 3.5,  6.3,  7.4, 11.2]),
#  'FGA': array([ 7.6, 12.9, 15.5, 23.1]),
#  'FG%': array([0.369, 0.453, 0.5  , 0.664]),
#  '2P': array([ 2.2,  4.7,  6.1, 10.2]),
#  '2PA': array([ 4. ,  9.1, 11.5, 17.3]),
#  '2P%': array([0.376, 0.497, 0.541, 0.664]),
#  '3P': array([0. , 0.8, 2. , 4.6]),
#  '3PA': array([ 0. ,  2.2,  5.4, 11.2]),
#  '3P%': array([0.   , 0.304, 0.377, 0.6  ]),
#  'FT': array([1.1, 3.8, 5. , 8.7]),
#  'FTA': array([ 1.9,  5.1,  6.8, 11.6]),
#  'FT%': array([0.295, 0.706, 0.783, 0.925]),
#  'TRB': array([ 2.8,  6.1,  9.6, 16.7]),
#  'AST': array([ 0.2,  1.9,  3.4, 11.8]),
#  'STL': array([0.3, 1.1, 1.6, 3.5]),
#  'BLK': array([0. , 0.5, 1.2, 5.8]),
#  'TOV': array([1. , 2.3, 3. , 5. ]),
#  'PF': array([1.4, 2.5, 3.2, 7.6]),
#  'PTS': array([ 9.9, 17.8, 21.1, 32.3]),
#  'ORtg': array([ 95.5, 113.4, 119.2, 139. ]),
#  'DRtg': array([ 78.1,  93.1,  99.6, 112.2]),
#  'PER': array([11.9, 21.9, 25.9, 36.2]),
#  'TS%': array([0.485, 0.555, 0.59 , 0.697]),
#  'eFG%': array([0.438, 0.513, 0.552, 0.664]),
#  '3PAr': array([0.   , 0.178, 0.362, 0.666]),
#  'FTr': array([0.18 , 0.362, 0.462, 0.908]),
#  'ORB%': array([ 0.5,  3.8,  9. , 20. ]),
#  'DRB%': array([ 7. , 13.2, 19.2, 33. ]),
#  'TRB%': array([ 4.2,  9. , 14.1, 25.6]),
#  'AST%': array([ 0.9, 10.5, 18.4, 50. ]),
#  'STL%': array([0.4, 1.7, 2.3, 5. ]),
#  'BLK%': array([ 0.1,  1.4,  3.4, 13.7]),
#  'TOV%': array([ 5.7, 12. , 14.7, 27.8]),
#  'AST:TOV': array([0.05882353, 0.79411765, 1.375     , 3.61904762]),
#  'Hght\n(inches)': array([69., 78., 81., 85.]),
#  'Weight': array([160., 205., 230., 279.]),
#  'RSCI Rank': array([  1.        ,  24.        ,  45.59668508, 251.        ]),
#  'Max Measured Wingspan (inches)': array([71.  , 81.25, 84.5 , 90.25]),
#  'Avg Measured Wingspan (inches': array([70.88, 80.58, 84.  , 90.25]),
#  'Difference': array([-2.25,  3.  ,  4.5 ,  8.25])}

# %%
clf.transform(X).head()
# Out:
#          Pk       Age       SOS        FG       FGA       FG%        2P  \
# 0 -1.347467 -0.618601  0.094090 -0.257153 -0.064679 -0.279626 -0.161843
# 1 -1.347467 -0.618601 -0.303494 -0.257153 -0.064679  0.353623  0.146892
# 2 -1.347467  0.006780 -0.303494  0.158629  0.221149  0.353623  0.006780
# 3 -1.347467  0.531304  0.177664  0.158629  0.221149  0.353623  0.006780
# 4 -0.013423  0.531304  0.094090  0.158629  0.221149 -0.104685  0.006780
#
#         2PA       2P%        3P  ...      STL%      BLK%      TOV%   AST:TOV  \
# 0 -0.106783 -0.340535  0.125839  ... -0.449525 -0.438096  0.115144  0.115144
# 1 -0.106783  0.279990  0.125839  ...  0.391542  0.279990  0.115144 -0.322186
# 2 -0.064679  0.279990 -0.220112  ... -0.449525  0.279990  0.146892  0.115144
# 3 -0.064679  0.279990  0.125839  ... -0.039241  0.279990 -0.279626 -0.322186
# 4 -0.064679  0.027399 -0.220112  ... -0.039241  0.279990  0.115144  0.115144
#
#    Hght\n(inches)   Weight  RSCI Rank  Max Measured Wingspan (inches)  \
# 0        0.265601  0.27999  -0.333693                        0.174629
# 1        0.265601  0.27999  -0.333693                        0.174629
# 2        0.265601  0.27999  -0.333693                        0.174629
# 3        0.265601  0.27999   0.243622                        0.174629
# 4        0.265601  0.27999  -0.333693                        0.174629
#
#    Avg Measured Wingspan (inches  Difference
# 0                       0.251002   -0.095152
# 1                       0.251002   -0.227801
# 2                       0.251002   -0.095152
# 3                       0.251002   -0.095152
# 4                       0.251002   -0.227801
#
# [5 rows x 43 columns]

# %%
from xverse.graph import BarCharts

# %%
woe_df = clf.woe_df

# %%
clf = BarCharts(bar_type='v')

# %%
clf.plot(woe_df)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:338: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /opt/anaconda3/lib/python3.7/site-packages/xverse/graph/_bivariate_charts.py:152: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
# BarCharts(bar_color='#058caa', bar_type='v', exclude_features=None,
#           feature_names='all', fig_size=(8, 6), num_color='#ed8549',
#           plot_metric='mean')

# %%
from xverse.ensemble import VotingSelector

clf = VotingSelector()
clf.fit(X, y)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# VotingSelector(exclude_features=None, feature_names='all',
#                handle_category='woe', minimum_votes=0, no_of_features=21,
#                numerical_missing_values='median',
#                selection_techniques=['WOE', 'RF', 'RFE', 'ETC', 'CS', 'L_ONE'])

# %%
clf.available_techniques
# Out:
# ['WOE', 'RF', 'RFE', 'ETC', 'CS', 'L_ONE']

# %%
clf.feature_importances_
# Out:
#                      Variable_Name  Information_Value  Random_Forest  \
# 0                               Pk           0.894739       0.117924
# 1                              Age           0.213868       0.051706
# 2                              TRB           0.170763       0.025788
# 3                              STL           0.161579       0.024425
# 4                             DRB%           0.158666       0.048783
# 5                             ORB%           0.140723       0.014988
# 6                              FTr           0.133697       0.038293
# 7                             DRtg           0.124035       0.018042
# 8                             STL%           0.120378       0.031078
# 9    Avg Measured Wingspan (inches           0.098820       0.021800
# 10                            TRB%           0.096325       0.052108
# 11                            BLK%           0.093542       0.013903
# 12                             FG%           0.072058       0.016996
# 13                             3P%           0.071163       0.016761
# 14                             2P%           0.064278       0.033395
# 15                            eFG%           0.063945       0.010437
# 16                  Hght\n(inches)           0.062306       0.010454
# 17                              FT           0.062123       0.013152
# 18                       RSCI Rank           0.060642       0.019860
# 19                             AST           0.055255       0.009970
# 20                             PTS           0.052774       0.017006
# 21                      Difference           0.047847       0.035465
# 22                         AST:TOV           0.047810       0.037934
# 23                          Weight           0.045496       0.009071
# 24                             BLK           0.044904       0.015520
# 25                             SOS           0.042430       0.008317
# 26                             TS%           0.038102       0.011196
# 27                            TOV%           0.036731       0.033663
# 28  Max Measured Wingspan (inches)           0.034232       0.011309
# 29                              FG           0.032971       0.009186
# 30                             FGA           0.026808       0.024603
# 31                             PER           0.026655       0.022478
# 32                             FTA           0.024455       0.020169
# 33                              3P           0.023253       0.015488
# 34                             FT%           0.022918       0.014715
# 35                             3PA           0.020041       0.017015
# 36                            AST%           0.015893       0.021764
# 37                              2P           0.015893       0.010234
# 38                             2PA           0.014814       0.019972
# 39                            3PAr           0.009501       0.021891
# 40                            ORtg           0.006793       0.017562
# 41                              PF           0.006085       0.008226
# 42                             TOV           0.001930       0.007353
#
#     Recursive_Feature_Elimination  Extra_Trees  Chi_Square     L_One
# 0                        0.000000     0.096603    8.281862  0.027250
# 1                        0.000000     0.042741    1.178903  0.000000
# 2                       -0.150317     0.012764    0.611717  0.000000
# 3                       -0.139277     0.021665    0.292514  0.000000
# 4                        0.000000     0.030542    0.911295 -0.012905
# 5                        0.132675     0.016712    0.274616  0.000000
# 6                       -0.266117     0.032023    0.010928  0.000000
# 7                        0.000000     0.012679    0.560687  0.000000
# 8                        0.000000     0.032435    0.346931  0.000000
# 9                        0.137079     0.019184    0.066707  0.000000
# 10                       0.000000     0.022101    0.674687  0.000000
# 11                       0.232988     0.027887    0.036520  0.000000
# 12                       0.000000     0.014130    0.198672  0.000000
# 13                       0.589435     0.031789    0.123516  0.000000
# 14                      -0.083680     0.018859    0.325635  0.000000
# 15                       0.000000     0.016351    0.171249  0.000000
# 16                       0.000000     0.021361    0.173669 -0.007103
# 17                       0.000000     0.018539    0.039186  0.000000
# 18                       0.000000     0.018236    0.058488 -0.001948
# 19                       0.531149     0.012806    0.025438  0.000000
# 20                       0.513550     0.010395    0.016450  0.000000
# 21                       0.000000     0.017867    0.020149  0.000000
# 22                       0.000000     0.025794    0.004764  0.000000
# 23                       0.000000     0.019848    0.082848  0.000000
# 24                       0.000000     0.020933    0.037670  0.000000
# 25                       0.000000     0.017438    0.045100  0.000000
# 26                       0.000000     0.026605    0.064429  0.000000
# 27                       0.183514     0.023444    0.000755  0.000000
# 28                      -0.156248     0.033176    0.075917  0.000000
# 29                       0.000000     0.024875    0.000009  0.000000
# 30                      -0.245024     0.017512    0.050080  0.000000
# 31                      -0.262042     0.015588    0.220971  0.000000
# 32                       0.000000     0.016648    0.011866  0.000000
# 33                       0.000000     0.015223    0.137811  0.000000
# 34                       0.267100     0.019760    0.022204  0.000000
# 35                       0.000000     0.035332    0.109461  0.000000
# 36                      -0.074398     0.023836    0.002016 -0.005152
# 37                      -0.536152     0.016101    0.042207  0.000000
# 38                       0.363381     0.025528    0.000327  0.000000
# 39                      -0.186732     0.010976    0.041635  0.000000
# 40                       0.000000     0.018949    0.039934 -0.000090
# 41                      -0.300478     0.020770    0.041383  0.000000
# 42                      -0.990765     0.023995    0.013735  0.000000

# %%
clf.feature_votes_
# Out:
#                      Variable_Name  Information_Value  Random_Forest  \
# 3                              STL                  1              1
# 0                               Pk                  1              1
# 8                             STL%                  1              1
# 1                              Age                  1              1
# 14                             2P%                  1              1
# 10                            TRB%                  1              1
# 9    Avg Measured Wingspan (inches                  1              1
# 13                             3P%                  1              0
# 4                             DRB%                  1              1
# 2                              TRB                  1              1
# 6                              FTr                  1              1
# 7                             DRtg                  1              1
# 5                             ORB%                  1              0
# 11                            BLK%                  1              0
# 36                            AST%                  0              1
# 16                  Hght\n(inches)                  1              0
# 38                             2PA                  0              1
# 31                             PER                  0              1
# 28  Max Measured Wingspan (inches)                  0              0
# 18                       RSCI Rank                  1              1
# 15                            eFG%                  1              0
# 27                            TOV%                  0              1
# 12                             FG%                  1              0
# 39                            3PAr                  0              1
# 35                             3PA                  0              0
# 30                             FGA                  0              1
# 41                              PF                  0              0
# 42                             TOV                  0              0
# 26                             TS%                  0              0
# 22                         AST:TOV                  0              1
# 20                             PTS                  1              0
# 19                             AST                  1              0
# 17                              FT                  1              0
# 29                              FG                  0              0
# 24                             BLK                  0              0
# 32                             FTA                  0              1
# 33                              3P                  0              0
# 34                             FT%                  0              0
# 23                          Weight                  0              0
# 37                              2P                  0              0
# 40                            ORtg                  0              0
# 21                      Difference                  0              1
# 25                             SOS                  0              0
#
#     Recursive_Feature_Elimination  Extra_Trees  Chi_Square  L_One  Votes
# 3                               1            1           1      1      6
# 0                               0            1           1      1      5
# 8                               0            1           1      1      5
# 1                               0            1           1      1      5
# 14                              1            0           1      1      5
# 10                              0            1           1      1      5
# 9                               1            0           1      1      5
# 13                              1            1           1      1      5
# 4                               0            1           1      1      5
# 2                               1            0           1      1      5
# 6                               1            1           0      1      5
# 7                               0            0           1      1      4
# 5                               1            0           1      1      4
# 11                              1            1           0      1      4
# 36                              1            1           0      1      4
# 16                              0            1           1      1      4
# 38                              1            1           0      0      3
# 31                              1            0           1      0      3
# 28                              1            1           1      0      3
# 18                              0            0           0      1      3
# 15                              0            0           1      1      3
# 27                              1            1           0      0      3
# 12                              0            0           1      1      3
# 39                              1            0           0      0      2
# 35                              0            1           1      0      2
# 30                              1            0           0      0      2
# 41                              1            1           0      0      2
# 42                              1            1           0      0      2
# 26                              0            1           1      0      2
# 22                              0            1           0      0      2
# 20                              1            0           0      0      2
# 19                              1            0           0      0      2
# 17                              0            0           0      1      2
# 29                              0            1           0      0      1
# 24                              0            1           0      0      1
# 32                              0            0           0      0      1
# 33                              0            0           1      0      1
# 34                              1            0           0      0      1
# 23                              0            0           1      0      1
# 37                              1            0           0      0      1
# 40                              0            0           0      1      1
# 21                              0            0           0      0      1
# 25                              0            0           0      0      0

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
list(df.columns)
# Out:
# ['Player',
#  'Pk',
#  'Age',
#  'SOS',
#  'FG',
#  'FGA',
#  'FG%',
#  '2P',
#  '2PA',
#  '2P%',
#  '3P',
#  '3PA',
#  '3P%',
#  'FT',
#  'FTA',
#  'FT%',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS',
#  'ORtg',
#  'DRtg',
#  'PER',
#  'TS%',
#  'eFG%',
#  '3PAr',
#  'FTr',
#  'ORB%',
#  'DRB%',
#  'TRB%',
#  'AST%',
#  'STL%',
#  'BLK%',
#  'TOV%',
#  'AST:TOV',
#  'Hght\n(inches)',
#  'Weight',
#  'RSCI Rank',
#  'Max Measured Wingspan (inches)',
#  'Avg Measured Wingspan (inches',
#  'Difference',
#  'Bust']

# %%
import seaborn as sns

# %%
sns.pairplot(df[['STL','Pk', 'Age', '2P%','TRB%','Avg Measured Wingspan (inches', '3P%','FTr',
                 'Bust']], hue='Bust',kind="scatter",plot_kws=dict(s=80, edgecolor="white", linewidth=2.5))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
import numpy as np

from sklearn.model_selection import StratifiedKFold
from yellowbrick.model_selection import LearningCurve

# Create the learning curve visualizer
cv = StratifiedKFold(n_splits=12)
sizes = np.linspace(0.3, 1.0, 10)

# Instantiate the classification model and visualizer
model = LogisticRegression(solver='liblinear', random_state=2)
visualizer = LearningCurve(
    model, cv=cv, scoring='roc_auc', train_sizes=sizes, n_jobs=4
)

visualizer.fit(X, y)        # Fit the data to the visualizer
visualizer.show()           # Finalize and render the figure
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/yellowbrick/base.py:246: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
from sklearn.model_selection import StratifiedKFold
from yellowbrick.model_selection import CVScores

# Create a cross-validation strategy
cv = StratifiedKFold(n_splits=12, random_state=42)

# Instantiate the classification model and visualizer
model = LogisticRegression(solver='liblinear', random_state=2)
visualizer = CVScores(model, cv=cv, scoring='roc_auc')

visualizer.fit(X, y)        # Fit the data to the visualizer
visualizer.show()           # Finalize and render the figure
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/yellowbrick/base.py:246: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
sns.pairplot(df[['STL','Pk', 'Age', '2P%','TRB%','Avg Measured Wingspan (inches', '3P%','FTr',
                 'Bust']], hue='Bust',kind="scatter",plot_kws=dict(s=80, edgecolor="white", linewidth=2.5))

# %%
X = df.drop(['SOS','FG','FG%','FGA','2P','2PA','3P','FT','FT%','FTA','TRB', 'Player', '3PA','PTS','PER',
 'BLK','TOV','PF','ORtg','DRtg','TS%','eFG%','3PAr','Bust', 'DRB%','ORB%',
 'AST','STL%','BLK%','TOV%','AST:TOV','Hght\n(inches)', 'Weight','RSCI Rank', 'Max Measured Wingspan (inches)',
 'Difference'], axis=1)
y = df['Bust']

# %%
X
# Out:
#      Pk     Age    2P%    3P%  STL    FTr  TRB%  AST%  \
# 0     1  19.096  0.569  0.462  2.1  0.683   6.7  29.8
# 1     8  19.208  0.461  0.377  0.7  0.333   6.3  23.4
# 2     9  21.051  0.471  0.330  2.0  0.426   7.9  28.0
# 3    10  22.123  0.491  0.396  1.5  0.369   5.2  28.8
# 4    21  22.338  0.501  0.350  1.4  0.405   7.2  30.3
# ..   ..     ...    ...    ...  ...    ...   ...   ...
# 230   3  19.197  0.664  0.000  1.0  0.462  16.6   9.4
# 231   9  20.257  0.646  0.000  0.8  0.674  17.4  13.9
# 232  37  19.239  0.623  0.000  1.3  0.253  19.8  12.9
# 233  40  19.138  0.568  0.000  0.9  0.456  13.6   4.2
# 234  41  19.292  0.492  0.294  0.8  0.472  17.7   6.4
#
#      Avg Measured Wingspan (inches
# 0                            75.67
# 1                            78.38
# 2                            74.50
# 3                            76.75
# 4                            77.88
# ..                             ...
# 230                          89.06
# 231                          85.88
# 232                          86.63
# 233                          86.89
# 234                          86.80
#
# [235 rows x 9 columns]

# %%
import numpy as np

from sklearn.model_selection import StratifiedKFold
from yellowbrick.model_selection import LearningCurve

# Create the learning curve visualizer
cv = StratifiedKFold(n_splits=12)
sizes = np.linspace(0.3, 1.0, 10)

# Instantiate the classification model and visualizer
model = LogisticRegression(solver='liblinear', random_state=2)
visualizer = LearningCurve(
    model, cv=cv, scoring='roc_auc', train_sizes=sizes, n_jobs=4
)

visualizer.fit(X, y)        # Fit the data to the visualizer
visualizer.show()           # Finalize and render the figure
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/yellowbrick/base.py:246: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
from sklearn.model_selection import StratifiedKFold
from yellowbrick.model_selection import CVScores

# Create a cross-validation strategy
cv = StratifiedKFold(n_splits=12, random_state=42)

# Instantiate the classification model and visualizer
model = LogisticRegression(solver='liblinear', random_state=2)
visualizer = CVScores(model, cv=cv, scoring='roc_auc')

visualizer.fit(X, y)        # Fit the data to the visualizer
visualizer.show()           # Finalize and render the figure
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/yellowbrick/base.py:246: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
X
# Out:
#        FG%    2P%  3PA   FT   PTS   PER  AST%
# 0    0.529  0.569  5.1  8.4  25.3  32.5  29.8
# 1    0.423  0.461  6.8  4.0  19.3  19.3  23.4
# 2    0.428  0.471  5.9  6.7  25.0  29.9  28.0
# 3    0.452  0.491  9.5  7.6  32.3  30.9  28.8
# 4    0.458  0.501  5.2  5.9  24.3  25.7  30.3
# ..     ...    ...  ...  ...   ...   ...   ...
# 230  0.664  0.664  0.0  3.5  23.0  30.7   9.4
# 231  0.646  0.646  0.0  6.0  22.7  31.1  13.9
# 232  0.620  0.623  0.1  1.7  16.1  26.4  12.9
# 233  0.568  0.568  0.0  5.1  21.6  26.6   4.2
# 234  0.477  0.492  1.0  3.7  16.0  17.6   6.4
#
# [235 rows x 7 columns]

# %%
features = ['STL','Pk', 'Age', '2P%','TRB%','Avg Measured Wingspan (inches', '3P%','FTr','AST%']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
logreg = LogisticRegression(solver='liblinear', random_state=2).fit(x_train, y_train)
y_scores_logreg = logreg.predict_proba(x_test)[:,1]
y_pred_logreg = logreg.predict(x_test)

print("Train accuracy:",logreg.score(x_train, y_train))
print("Test accuracy:", logreg.score(x_test, y_test))
print("ROC AUC:", roc_auc_score(y_test, y_scores_logreg))

ax = pd.DataFrame(
    logreg.coef_.transpose(),
    index=features,
    columns=['coefficients']
).sort_values('coefficients').plot(
    kind='barh', legend=False, title='Logistic Regression Feature Coefficients', figsize=(10,5), fontsize=14
)

ax.title.set_size(16)
# Out:
# Train accuracy: 0.7102272727272727
# Test accuracy: 0.7288135593220338
# ROC AUC: 0.7

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

# %%
xg_cl = xgb.XGBClassifier()

# %%
params = {"max_depth": [10,30,50],
              "min_child_weight" : [1,3,6],
              "n_estimators": [200],
              "learning_rate": [0.05, 0.1,0.16],}

# %%
grid_search = GridSearchCV(xg_cl, params, cv = 3, verbose=10, n_jobs=-1)

# %%
grid_search.fit(X_train, Y_train)
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1950s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1329s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done  66 out of  81 | elapsed:    3.4s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done  75 out of  81 | elapsed:    3.4s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  81 out of  81 | elapsed:    3.4s finished
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      colsample_bylevel=1, colsample_bynode=1,
#                                      colsample_bytree=1, gamma=0,
#                                      learning_rate=0.1, max_delta_step=0,
#                                      max_depth=3, min_child_weight=1,
#                                      missing=None, n_estimators=100, n_jobs=1,
#                                      nthread=None, objective='binary:logistic',
#                                      random_state=0, reg_alpha=0, reg_lambda=1,
#                                      scale_pos_weight=1, seed=None, silent=None,
#                                      subsample=1, verbosity=1),
#              iid='warn', n_jobs=-1,
#              param_grid={'learning_rate': [0.05, 0.1, 0.16],
#                          'max_depth': [10, 30, 50],
#                          'min_child_weight': [1, 3, 6], 'n_estimators': [200]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=10)

# %%
grid_search.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.16, max_delta_step=0, max_depth=10,
#               min_child_weight=6, missing=None, n_estimators=200, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score

# %%
xg = xgb.XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=1, gamma=0,
              learning_rate=0.16, max_delta_step=0, max_depth=10,
              min_child_weight=6, missing=None, n_estimators=200, n_jobs=1,
              nthread=None, objective='binary:logistic', random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
              silent=None, subsample=1, verbosity=1).fit(X_train, Y_train)
y_scores_xg = xg.predict_proba(X_test)[:,1]

print("Train Accuracy:",xg.score(X_train, Y_train))
print("Test Accuracy:", xg.score(X_test, Y_test))
print("ROC AUC:", roc_auc_score(Y_test, y_scores_xg))
# Out:
# Train Accuracy: 0.9488636363636364
# Test Accuracy: 0.6949152542372882
# ROC AUC: 0.65

# %%
xg_roc_auc = roc_auc_score(Y_test, y_scores_xg)
fpr, tpr, thresholds = metrics.roc_curve(Y_test, y_scores_xg)
plt.plot(fpr, tpr, label='XGBoost (AUC = %0.2f)' % xg_roc_auc)
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Random Model', alpha=.8)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   if sys.path[0] == '':

# %%
import shap

# %%
explainer = shap.TreeExplainer(xg)

# %%
shap_values = explainer.shap_values(X_train)

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...

# %%
shap.summary_plot(shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/summary.py:464: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
shap.summary_plot(shap_values, X_train, plot_type="bar")

# %%
shap.dependence_plot('Pk', shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/dependence.py:291: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
shap.dependence_plot("AST%", shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/dependence.py:291: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
shap.dependence_plot("FTr", shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/dependence.py:291: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
shap.dependence_plot("TRB%", shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/dependence.py:291: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
shap.dependence_plot("Avg Measured Wingspan (inches", shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/dependence.py:291: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
shap.dependence_plot("3P%", shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/dependence.py:291: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
shap.dependence_plot("2P%", shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/dependence.py:291: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
shap.dependence_plot("Age", shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/dependence.py:291: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
shap.dependence_plot("STL", shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/dependence.py:291: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()
