# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('2011-16 Bench.xlsx')
df
# Out:
#                 Player  Pk     Age    SOS    FG   FGA    FG%   2P   2PA  \
# 0         Kyrie Irving   1  19.096   8.31   7.3  13.7  0.529  4.9   8.6
# 1       Brandon Knight   8  19.208   8.91   6.4  15.1  0.423  3.8   8.3
# 2         Kemba Walker   9  21.051  10.44   8.2  19.2  0.428  6.2  13.3
# 3      Jimmer Fredette  10  22.123   5.76  10.5  23.1  0.452  6.7  13.7
# 4          Nolan Smith  21  22.338   8.31   8.3  18.0  0.458  6.4  12.9
# ..                 ...  ..     ...    ...   ...   ...    ...  ...   ...
# 230      Jahlil Okafor   3  19.197   9.87   9.8  14.7  0.664  9.8  14.7
# 231       Jakob Poeltl   9  20.257   8.79   8.3  12.9  0.646  8.3  12.9
# 232     Chinanu Onuaku  37  19.239   7.74   7.2  11.6  0.620  7.2  11.5
# 233      Diamond Stone  40  19.138   8.31   8.3  14.6  0.568  8.3  14.6
# 234  Stephen Zimmerman  41  19.292   3.17   6.0  12.6  0.477  5.7  11.6
#
#        2P%  ...  BLK%  TOV%   AST:TOV  Hght\n(inches)  Weight  RSCI Rank  \
# 0    0.569  ...   1.8  16.4  1.722222              75     193        3.0
# 1    0.461  ...   0.6  16.8  1.342857              75     195        5.0
# 2    0.471  ...   0.5   9.5  2.000000              73     184       16.0
# 3    0.491  ...   0.1  12.7  1.200000              74     195        NaN
# 4    0.501  ...   0.2  14.8  1.621622              74     190       19.0
# ..     ...  ...   ...   ...       ...             ...     ...        ...
# 230  0.664  ...   4.5  15.6  0.515152              83     260        2.0
# 231  0.646  ...   5.0  13.7  0.962963              84     248        NaN
# 232  0.623  ...   9.6  20.8  0.794118              82     245       63.0
# 233  0.568  ...   7.1  12.9  0.269231              83     255        6.0
# 234  0.492  ...   7.5  17.1  0.406250              84     240        9.0
#
#      Max Measured Wingspan (inches)  Avg Measured Wingspan (inches  \
# 0                             76.00                          75.67
# 1                             78.75                          78.38
# 2                             75.50                          74.50
# 3                             77.00                          76.75
# 4                             78.00                          77.88
# ..                              ...                            ...
# 230                           90.25                          89.06
# 231                           86.75                          85.88
# 232                           86.75                          86.63
# 233                           88.00                          86.89
# 234                           87.25                          86.80
#
#      Difference  Bench
# 0          1.00      0
# 1          3.75      1
# 2          2.50      0
# 3          3.00      0
# 4          4.00      0
# ..          ...    ...
# 230        7.25      1
# 231        2.75      1
# 232        4.75      0
# 233        5.00      0
# 234        3.25      0
#
# [235 rows x 45 columns]

# %%
import dabl

# %%
df['RSCI Rank'] = pd.to_numeric(df['RSCI Rank'], errors='coerce')
df['RSCI Rank'] = df['RSCI Rank'].fillna(df['RSCI Rank'].mean())

# %%
dabl.plot(df, target_col="Bench")
# Out:
# Target looks like classification
# Showing only top 10 of 43 continuous features
# Linear Discriminant Analysis training set score: 0.611
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")

# %%
sc = dabl.SimpleClassifier()
sc.fit(df, target_col='Bench')
# Out:
# Running DummyClassifier(strategy='prior')
# accuracy: 0.694 average_precision: 0.306 roc_auc: 0.500 recall_macro: 0.500 f1_macro: 0.410
# === new best DummyClassifier(strategy='prior') (using recall_macro):
# accuracy: 0.694 average_precision: 0.306 roc_auc: 0.500 recall_macro: 0.500 f1_macro: 0.410
#
# Running GaussianNB()
# accuracy: 0.572 average_precision: 0.315 roc_auc: 0.440 recall_macro: 0.480 f1_macro: 0.408
# Running MultinomialNB()
# accuracy: 0.650 average_precision: 0.350 roc_auc: 0.445 recall_macro: 0.497 f1_macro: 0.458
# Running DecisionTreeClassifier(class_weight='balanced', max_depth=1)
# accuracy: 0.366 average_precision: 0.314 roc_auc: 0.515 recall_macro: 0.515 f1_macro: 0.340
# === new best DecisionTreeClassifier(class_weight='balanced', max_depth=1) (using recall_macro):
# accuracy: 0.366 average_precision: 0.314 roc_auc: 0.515 recall_macro: 0.515 f1_macro: 0.340
#
# Running DecisionTreeClassifier(class_weight='balanced', max_depth=5)
# accuracy: 0.558 average_precision: 0.356 roc_auc: 0.547 recall_macro: 0.557 f1_macro: 0.525
# === new best DecisionTreeClassifier(class_weight='balanced', max_depth=5) (using recall_macro):
# accuracy: 0.558 average_precision: 0.356 roc_auc: 0.547 recall_macro: 0.557 f1_macro: 0.525
#
# Running DecisionTreeClassifier(class_weight='balanced', min_impurity_decrease=0.01)
# accuracy: 0.583 average_precision: 0.349 roc_auc: 0.525 recall_macro: 0.524 f1_macro: 0.520
# Running LogisticRegression(C=0.1, class_weight='balanced', max_iter=1000, solver='lbfgs')
# accuracy: 0.505 average_precision: 0.318 roc_auc: 0.470 recall_macro: 0.465 f1_macro: 0.459
# Running LogisticRegression(class_weight='balanced', max_iter=1000, solver='lbfgs')
# accuracy: 0.476 average_precision: 0.300 roc_auc: 0.452 recall_macro: 0.428 f1_macro: 0.418
#
# Best model:
# DecisionTreeClassifier(class_weight='balanced', max_depth=5)
# Best Scores:
# accuracy: 0.558 average_precision: 0.356 roc_auc: 0.547 recall_macro: 0.557 f1_macro: 0.525
# SimpleClassifier(random_state=None, refit=True, shuffle=True, type_hints=None,
#                  verbose=1)

# %%
X = df.drop(['Bench', 'Player'], axis=1)
y = df['Bench']

# %%
from xverse.transformer import MonotonicBinning

clf = MonotonicBinning()
clf.fit(X, y)
# Out:
# MonotonicBinning(cardinality_cutoff=5, custom_binning=None, feature_names='all',
#                  force_bins=4, max_bins=20, prefix=None)

# %%
clf.bins
# Out:
# {'Pk': array([ 1., 17., 34., 60.]),
#  'Age': array([18.242, 20.176, 22.024, 27.148]),
#  'SOS': array([-5.39,  7.17,  8.31, 12.13]),
#  'FG': array([ 3.5,  6.3,  7.4, 11.2]),
#  'FGA': array([ 7.6, 12.9, 15.5, 23.1]),
#  'FG%': array([0.369, 0.453, 0.5  , 0.664]),
#  '2P': array([ 2.2,  4.7,  6.1, 10.2]),
#  '2PA': array([ 4. ,  9.1, 11.5, 17.3]),
#  '2P%': array([0.376, 0.497, 0.541, 0.664]),
#  '3P': array([0. , 0.8, 2. , 4.6]),
#  '3PA': array([ 0. ,  2.2,  5.4, 11.2]),
#  '3P%': array([0.   , 0.304, 0.377, 0.6  ]),
#  'FT': array([1.1, 3.8, 5. , 8.7]),
#  'FTA': array([ 1.9,  5.1,  6.8, 11.6]),
#  'FT%': array([0.295, 0.706, 0.783, 0.925]),
#  'TRB': array([ 2.8,  6.1,  9.6, 16.7]),
#  'AST': array([ 0.2,  1.9,  3.4, 11.8]),
#  'STL': array([0.3, 1.1, 1.6, 3.5]),
#  'BLK': array([0. , 0.5, 1.2, 5.8]),
#  'TOV': array([1. , 2.3, 3. , 5. ]),
#  'PF': array([1.4, 2.5, 3.2, 7.6]),
#  'PTS': array([ 9.9, 17.8, 21.1, 32.3]),
#  'ORtg': array([ 95.5, 113.4, 119.2, 139. ]),
#  'DRtg': array([ 78.1,  93.1,  99.6, 112.2]),
#  'PER': array([11.9, 21.9, 25.9, 36.2]),
#  'TS%': array([0.485, 0.555, 0.59 , 0.697]),
#  'eFG%': array([0.438, 0.513, 0.552, 0.664]),
#  '3PAr': array([0.   , 0.178, 0.362, 0.666]),
#  'FTr': array([0.18 , 0.362, 0.462, 0.908]),
#  'ORB%': array([ 0.5,  3.8,  9. , 20. ]),
#  'DRB%': array([ 7. , 13.2, 19.2, 33. ]),
#  'TRB%': array([ 4.2,  9. , 14.1, 25.6]),
#  'AST%': array([ 0.9, 10.5, 18.4, 50. ]),
#  'STL%': array([0.4, 1.7, 2.3, 5. ]),
#  'BLK%': array([ 0.1,  1.4,  3.4, 13.7]),
#  'TOV%': array([ 5.7, 12. , 14.7, 27.8]),
#  'AST:TOV': array([0.05882353, 0.79411765, 1.375     , 3.61904762]),
#  'Hght\n(inches)': array([69., 78., 81., 85.]),
#  'Weight': array([160., 205., 230., 279.]),
#  'RSCI Rank': array([  1.        ,  24.        ,  45.59668508, 251.        ]),
#  'Max Measured Wingspan (inches)': array([71.  , 81.25, 84.5 , 90.25]),
#  'Avg Measured Wingspan (inches': array([70.88, 80.58, 84.  , 90.25]),
#  'Difference': array([-2.25,  3.  ,  4.5 ,  8.25])}

# %%
output_bins = clf.bins #will be used later in this exercise

# %%
out_X = clf.transform(X)

# %%
out_X.head()
# Out:
#               Pk               Age             SOS           FG           FGA  \
# 0  (0.999, 17.0]  (18.241, 20.176]    (7.17, 8.31]   (6.3, 7.4]  (12.9, 15.5]
# 1  (0.999, 17.0]  (18.241, 20.176]   (8.31, 12.13]   (6.3, 7.4]  (12.9, 15.5]
# 2  (0.999, 17.0]  (20.176, 22.024]   (8.31, 12.13]  (7.4, 11.2]  (15.5, 23.1]
# 3  (0.999, 17.0]  (22.024, 27.148]  (-5.391, 7.17]  (7.4, 11.2]  (15.5, 23.1]
# 4   (17.0, 34.0]  (22.024, 27.148]    (7.17, 8.31]  (7.4, 11.2]  (15.5, 23.1]
#
#               FG%                         2P           2PA             2P%  \
# 0    (0.5, 0.664]                 (4.7, 6.1]  (3.999, 9.1]  (0.541, 0.664]
# 1  (0.368, 0.453]  (2.1990000000000003, 4.7]  (3.999, 9.1]  (0.375, 0.497]
# 2  (0.368, 0.453]                (6.1, 10.2]  (11.5, 17.3]  (0.375, 0.497]
# 3  (0.368, 0.453]                (6.1, 10.2]  (11.5, 17.3]  (0.375, 0.497]
# 4    (0.453, 0.5]                (6.1, 10.2]  (11.5, 17.3]  (0.497, 0.541]
#
#            3P  ...          STL%          BLK%           TOV%         AST:TOV  \
# 0  (2.0, 4.6]  ...    (2.3, 5.0]    (1.4, 3.4]   (14.7, 27.8]  (1.375, 3.619]
# 1  (2.0, 4.6]  ...  (0.399, 1.7]  (0.099, 1.4]   (14.7, 27.8]  (0.794, 1.375]
# 2  (0.8, 2.0]  ...    (2.3, 5.0]  (0.099, 1.4]  (5.699, 12.0]  (1.375, 3.619]
# 3  (2.0, 4.6]  ...    (1.7, 2.3]  (0.099, 1.4]   (12.0, 14.7]  (0.794, 1.375]
# 4  (0.8, 2.0]  ...    (1.7, 2.3]  (0.099, 1.4]   (14.7, 27.8]  (1.375, 3.619]
#
#    Hght\n(inches)            Weight       RSCI Rank  \
# 0  (68.999, 78.0]  (159.999, 205.0]   (0.999, 24.0]
# 1  (68.999, 78.0]  (159.999, 205.0]   (0.999, 24.0]
# 2  (68.999, 78.0]  (159.999, 205.0]   (0.999, 24.0]
# 3  (68.999, 78.0]  (159.999, 205.0]  (24.0, 45.597]
# 4  (68.999, 78.0]  (159.999, 205.0]   (0.999, 24.0]
#
#   Max Measured Wingspan (inches) Avg Measured Wingspan (inches     Difference
# 0                (70.999, 81.25]    (70.87899999999999, 80.58]  (-2.251, 3.0]
# 1                (70.999, 81.25]    (70.87899999999999, 80.58]     (3.0, 4.5]
# 2                (70.999, 81.25]    (70.87899999999999, 80.58]  (-2.251, 3.0]
# 3                (70.999, 81.25]    (70.87899999999999, 80.58]  (-2.251, 3.0]
# 4                (70.999, 81.25]    (70.87899999999999, 80.58]     (3.0, 4.5]
#
# [5 rows x 43 columns]

# %%
from xverse.transformer import WOE

clf = WOE()
clf.fit(X, y)
# Out:
# WOE(exclude_features=None, feature_names='all', mono_cardinality_cutoff=5,
#     mono_custom_binning={'2P': array([ 2.2,  4.7,  6.1, 10.2]),
#                          '2P%': array([0.376, 0.497, 0.541, 0.664]),
#                          '2PA': array([ 4. ,  9.1, 11.5, 17.3]),
#                          '3P': array([0. , 0.8, 2. , 4.6]),
#                          '3P%': array([0.   , 0.304, 0.377, 0.6  ]),
#                          '3PA': array([ 0. ,  2.2,  5.4, 11.2]),
#                          '3PAr': array([0.   , 0.178, 0.362, 0.666]),
#                          'AST': array([ 0.2,  1.9,  3.4,...
#               'PER': {Interval(11.899000000000001, 21.9, closed='right'): 0.3707969791622875,
#                       Interval(21.9, 25.9, closed='right'): -0.1945168298877728,
#                       Interval(25.9, 36.2, closed='right'): -0.24762665520172128},
#               'PF': {Interval(1.399, 2.5, closed='right'): 0.1616772292136087,
#                      Interval(2.5, 3.2, closed='right'): -0.10717481973262487,
#                      Interval(3.2, 7.6, closed='right'): -0.05838465556319297}, ...},
#     woe_prefix=None)

# %%
clf.woe_df.head(10)
# Out:
#   Variable_Name                   Category  Count  Event  Non_Event  \
# 0            2P  (2.1990000000000003, 4.7]     79     23         56
# 1            2P                 (4.7, 6.1]     78     26         52
# 2            2P                (6.1, 10.2]     78     23         55
# 3           2P%             (0.375, 0.497]     80     20         60
# 4           2P%             (0.497, 0.541]     77     23         54
# 5           2P%             (0.541, 0.664]     78     29         49
# 6           2PA               (3.999, 9.1]     81     28         53
# 7           2PA                (9.1, 11.5]     78     21         57
# 8           2PA               (11.5, 17.3]     76     23         53
# 9            3P              (-0.001, 0.8]     82     29         53
#
#    Event_Rate  Non_Event_Rate  Event_Distribution  Non_Event_Distribution  \
# 0    0.291139        0.708861            0.319444                0.343558
# 1    0.333333        0.666667            0.361111                0.319018
# 2    0.294872        0.705128            0.319444                0.337423
# 3    0.250000        0.750000            0.277778                0.368098
# 4    0.298701        0.701299            0.319444                0.331288
# 5    0.371795        0.628205            0.402778                0.300613
# 6    0.345679        0.654321            0.388889                0.325153
# 7    0.269231        0.730769            0.291667                0.349693
# 8    0.302632        0.697368            0.319444                0.325153
# 9    0.353659        0.646341            0.402778                0.325153
#
#         WOE  Information_Value
# 0 -0.072773           0.007956
# 1  0.123937           0.007956
# 2 -0.054755           0.007956
# 3 -0.281528           0.055748
# 4 -0.036406           0.055748
# 5  0.292560           0.055748
# 6  0.178997           0.022038
# 7 -0.181445           0.022038
# 8 -0.017714           0.022038
# 9  0.214088           0.026120

# %%
clf.iv_df
# Out:
#                      Variable_Name  Information_Value
# 31                              Pk           0.139634
# 18                             FG%           0.132061
# 23                             FTr           0.093228
# 20                              FT           0.086998
# 28                             PER           0.081987
# 15                            DRtg           0.075157
# 22                             FTA           0.067098
# 30                             PTS           0.066017
# 14                            DRB%           0.062726
# 24                  Hght\n(inches)           0.057634
# 1                              2P%           0.055748
# 16                      Difference           0.047503
# 6                             3PAr           0.047213
# 37                            TOV%           0.047102
# 5                              3PA           0.042530
# 8                             AST%           0.041138
# 4                              3P%           0.040305
# 11   Avg Measured Wingspan (inches           0.034986
# 7                              AST           0.034492
# 12                             BLK           0.034254
# 9                          AST:TOV           0.033319
# 36                             TOV           0.032357
# 19                             FGA           0.031364
# 32                       RSCI Rank           0.029893
# 39                            TRB%           0.026576
# 3                               3P           0.026120
# 35                            STL%           0.024092
# 25  Max Measured Wingspan (inches)           0.023784
# 38                             TRB           0.022785
# 2                              2PA           0.022038
# 42                            eFG%           0.021849
# 41                          Weight           0.019664
# 13                            BLK%           0.019059
# 34                             STL           0.017804
# 26                            ORB%           0.016577
# 17                              FG           0.016028
# 40                             TS%           0.014584
# 29                              PF           0.014236
# 10                             Age           0.009722
# 0                               2P           0.007956
# 33                             SOS           0.004701
# 21                             FT%           0.002707
# 27                            ORtg           0.002484

# %%
output_woe_bins = clf.woe_bins #future transformation

# %%
output_woe_bins
# Out:
# {'2P': {Interval(2.1990000000000003, 4.7, closed='right'): -0.07277339301529268,
#   Interval(4.7, 6.1, closed='right'): 0.12393690123076169,
#   Interval(6.1, 10.2, closed='right'): -0.0547548875126143},
#  '2P%': {Interval(0.375, 0.497, closed='right'): -0.28152820687740265,
#   Interval(0.497, 0.541, closed='right'): -0.03640574884441762,
#   Interval(0.541, 0.664, closed='right'): 0.2925596136665544},
#  '2PA': {Interval(3.999, 9.1, closed='right'): 0.17899667841378905,
#   Interval(9.1, 11.5, closed='right'): -0.18144474832042007,
#   Interval(11.5, 17.3, closed='right'): -0.017713615832265276},
#  '3P': {Interval(-0.001, 0.8, closed='right'): 0.21408799822505917,
#   Interval(0.8, 2.0, closed='right'): -0.11722515558612628,
#   Interval(2.0, 4.6, closed='right'): -0.12737752705014427},
#  '3P%': {Interval(-0.001, 0.304, closed='right'): 0.1616772292136087,
#   Interval(0.304, 0.377, closed='right'): 0.10488870626006709,
#   Interval(0.377, 0.6, closed='right'): -0.29891994958927176},
#  '3PA': {Interval(-0.001, 2.2, closed='right'): 0.27235690634903503,
#   Interval(2.2, 5.4, closed='right'): -0.20274732902428833,
#   Interval(5.4, 11.2, closed='right'): -0.08963719906729725},
#  '3PAr': {Interval(-0.001, 0.178, closed='right'): 0.23313619319575374,
#   Interval(0.178, 0.362, closed='right'): -0.29891994958927176,
#   Interval(0.362, 0.666, closed='right'): 0.024845998586530804},
#  'AST': {Interval(0.199, 1.9, closed='right'): 0.23313619319575374,
#   Interval(1.9, 3.4, closed='right'): -0.0547548875126143,
#   Interval(3.4, 11.8, closed='right'): -0.2125353353904512},
#  'AST%': {Interval(0.899, 10.5, closed='right'): 0.27235690634903503,
#   Interval(10.5, 18.4, closed='right'): -0.11722515558612628,
#   Interval(18.4, 50.0, closed='right'): -0.18144474832042007},
#  'AST:TOV': {Interval(0.0578, 0.794, closed='right'): 0.028626721426436793,
#   Interval(0.794, 1.375, closed='right'): 0.20089794236689,
#   Interval(1.375, 3.619, closed='right'): -0.24762665520172128},
#  'Age': {Interval(18.241, 20.176, closed='right'): -0.012195273093818355,
#   Interval(20.176, 22.024, closed='right'): -0.11722515558612628,
#   Interval(22.024, 27.148, closed='right'): 0.12393690123076169},
#  'Avg Measured Wingspan (inches': {Interval(70.87899999999999, 80.58, closed='right'): -0.2647210885610214,
#   Interval(80.58, 84.0, closed='right'): 0.0678474345797181,
#   Interval(84.0, 90.25, closed='right'): 0.18336032170156244},
#  'BLK': {Interval(-0.001, 0.5, closed='right'): -0.047913355695897504,
#   Interval(0.5, 1.2, closed='right'): -0.2125353353904512,
#   Interval(1.2, 5.8, closed='right'): 0.2372655865377648},
#  'BLK%': {Interval(0.099, 1.4, closed='right'): -0.15231647539739637,
#   Interval(1.4, 3.4, closed='right'): -0.03021377859649671,
#   Interval(3.4, 13.7, closed='right'): 0.18336032170156244},
#  'DRB%': {Interval(6.999, 13.2, closed='right'): -0.3493508032161637,
#   Interval(13.2, 19.2, closed='right'): 0.2574682938552844,
#   Interval(19.2, 33.0, closed='right'): 0.06566799310678596},
#  'DRtg': {Interval(78.09899999999999, 93.1, closed='right'): -0.07277339301529268,
#   Interval(93.1, 99.6, closed='right'): 0.3470804525449715,
#   Interval(99.6, 112.2, closed='right'): -0.3160143829485719},
#  'Difference': {Interval(-2.251, 3.0, closed='right'): 0.038414727792599704,
#   Interval(3.0, 4.5, closed='right'): 0.25177027274064656,
#   Interval(4.5, 8.25, closed='right'): -0.29891994958927176},
#  'FG': {Interval(3.499, 6.3, closed='right'): 0.1616772292136087,
#   Interval(6.3, 7.4, closed='right'): -0.03021377859649671,
#   Interval(7.4, 11.2, closed='right'): -0.14572666571834078},
#  'FG%': {Interval(0.368, 0.453, closed='right'): -0.5534619223610445,
#   Interval(0.453, 0.5, closed='right'): 0.2925596136665544,
#   Interval(0.5, 0.664, closed='right'): 0.1810953150707103},
#  'FGA': {Interval(7.598999999999999, 12.9, closed='right'): 0.17899667841378905,
#   Interval(12.9, 15.5, closed='right'): 0.04389419355722535,
#   Interval(15.5, 23.1, closed='right'): -0.24762665520172128},
#  'FT': {Interval(1.0990000000000002, 3.8, closed='right'): 0.12393690123076169,
#   Interval(3.8, 5.0, closed='right'): 0.2627733460849775,
#   Interval(5.0, 8.7, closed='right'): -0.4440471363751776},
#  'FT%': {Interval(0.294, 0.706, closed='right'): -0.07277339301529268,
#   Interval(0.706, 0.783, closed='right'): 0.0469758600946334,
#   Interval(0.783, 0.925, closed='right'): 0.024845998586530804},
#  'FTA': {Interval(1.899, 5.1, closed='right'): 0.2864558307285366,
#   Interval(5.1, 6.8, closed='right'): 0.006153865574378286,
#   Interval(6.8, 11.6, closed='right'): -0.3529871708595476},
#  'FTr': {Interval(0.179, 0.362, closed='right'): 0.3264611653422359,
#   Interval(0.362, 0.462, closed='right'): -0.41967854535821986,
#   Interval(0.462, 0.908, closed='right'): 0.04389419355722535},
#  'Hght\n(inches)': {Interval(68.999, 78.0, closed='right'): -0.11245187683346858,
#   Interval(78.0, 81.0, closed='right'): -0.1897206576242798,
#   Interval(81.0, 85.0, closed='right'): 0.3972302362304429},
#  'Max Measured Wingspan (inches)': {Interval(70.999, 81.25, closed='right'): -0.11573595203465861,
#   Interval(81.25, 84.5, closed='right'): -0.09047297011469345,
#   Interval(84.5, 90.25, closed='right'): 0.22929741688858796},
#  'ORB%': {Interval(0.499, 3.8, closed='right'): -0.012195273093818355,
#   Interval(3.8, 9.0, closed='right'): -0.15231647539739637,
#   Interval(9.0, 20.0, closed='right'): 0.16315761438404297},
#  'ORtg': {Interval(95.499, 113.4, closed='right'): -0.012195273093818355,
#   Interval(113.4, 119.2, closed='right'): 0.06566799310678596,
#   Interval(119.2, 139.0, closed='right'): -0.0547548875126143},
#  'PER': {Interval(11.899000000000001, 21.9, closed='right'): 0.3707969791622875,
#   Interval(21.9, 25.9, closed='right'): -0.1945168298877728,
#   Interval(25.9, 36.2, closed='right'): -0.24762665520172128},
#  'PF': {Interval(1.399, 2.5, closed='right'): 0.1616772292136087,
#   Interval(2.5, 3.2, closed='right'): -0.10717481973262487,
#   Interval(3.2, 7.6, closed='right'): -0.05838465556319297},
#  'PTS': {Interval(9.899000000000001, 17.8, closed='right'): 0.16030454540163672,
#   Interval(17.8, 21.1, closed='right'): 0.18336032170156244,
#   Interval(21.1, 32.3, closed='right'): -0.38688872253522893},
#  'Pk': {Interval(0.999, 17.0, closed='right'): -0.20274732902428833,
#   Interval(17.0, 34.0, closed='right'): 0.4849502467680923,
#   Interval(34.0, 60.0, closed='right'): -0.3750542648882262},
#  'RSCI Rank': {Interval(0.999, 24.0, closed='right'): -0.1694109087566966,
#   Interval(24.0, 45.597, closed='right'): -0.045962135564635756,
#   Interval(45.597, 251.0, closed='right'): 0.26369884360592033},
#  'SOS': {Interval(-5.391, 7.17, closed='right'): 0.08619657324791467,
#   Interval(7.17, 8.31, closed='right'): -0.012195273093818355,
#   Interval(8.31, 12.13, closed='right'): -0.08085751141525131},
#  'STL': {Interval(0.299, 1.1, closed='right'): 0.14195540673344,
#   Interval(1.1, 1.6, closed='right'): 0.010608215923758556,
#   Interval(1.6, 3.5, closed='right'): -0.1897206576242798},
#  'STL%': {Interval(0.399, 1.7, closed='right'): 0.1929297727177132,
#   Interval(1.7, 2.3, closed='right'): -0.07021911321019574,
#   Interval(2.3, 5.0, closed='right'): -0.16374517122101917},
#  'TOV': {Interval(0.999, 2.3, closed='right'): 0.22929741688858812,
#   Interval(2.3, 3.0, closed='right'): -0.09920665008344803,
#   Interval(3.0, 5.0, closed='right'): -0.1843644584237548},
#  'TOV%': {Interval(5.699, 12.0, closed='right'): -0.19883649103228931,
#   Interval(12.0, 14.7, closed='right'): 0.2925596136665544,
#   Interval(14.7, 27.8, closed='right'): -0.11722515558612628},
#  'TRB': {Interval(2.799, 6.1, closed='right'): -0.21593092439158942,
#   Interval(6.1, 9.6, closed='right'): 0.08471618807748044,
#   Interval(9.6, 16.7, closed='right'): 0.12393690123076169},
#  'TRB%': {Interval(4.199, 9.0, closed='right'): -0.23273804270797058,
#   Interval(9.0, 14.1, closed='right'): 0.10488870626006709,
#   Interval(14.1, 25.6, closed='right'): 0.12393690123076169},
#  'TS%': {Interval(0.484, 0.555, closed='right'): -0.15231647539739637,
#   Interval(0.555, 0.59, closed='right'): 0.006153865574378286,
#   Interval(0.59, 0.697, closed='right'): 0.14335498708786315},
#  'Weight': {Interval(159.999, 205.0, closed='right'): -0.09047297011469345,
#   Interval(205.0, 230.0, closed='right'): -0.09920665008344803,
#   Interval(230.0, 279.0, closed='right'): 0.20731851016981284},
#  'eFG%': {Interval(0.437, 0.513, closed='right'): -0.06530509840776678,
#   Interval(0.513, 0.552, closed='right'): -0.14572666571834078,
#   Interval(0.552, 0.664, closed='right'): 0.20089794236689}}

# %%
output_mono_bins = clf.mono_custom_binning  #future transformation

# %%
output_mono_bins
# Out:
# {'Pk': array([ 1., 17., 34., 60.]),
#  'Age': array([18.242, 20.176, 22.024, 27.148]),
#  'SOS': array([-5.39,  7.17,  8.31, 12.13]),
#  'FG': array([ 3.5,  6.3,  7.4, 11.2]),
#  'FGA': array([ 7.6, 12.9, 15.5, 23.1]),
#  'FG%': array([0.369, 0.453, 0.5  , 0.664]),
#  '2P': array([ 2.2,  4.7,  6.1, 10.2]),
#  '2PA': array([ 4. ,  9.1, 11.5, 17.3]),
#  '2P%': array([0.376, 0.497, 0.541, 0.664]),
#  '3P': array([0. , 0.8, 2. , 4.6]),
#  '3PA': array([ 0. ,  2.2,  5.4, 11.2]),
#  '3P%': array([0.   , 0.304, 0.377, 0.6  ]),
#  'FT': array([1.1, 3.8, 5. , 8.7]),
#  'FTA': array([ 1.9,  5.1,  6.8, 11.6]),
#  'FT%': array([0.295, 0.706, 0.783, 0.925]),
#  'TRB': array([ 2.8,  6.1,  9.6, 16.7]),
#  'AST': array([ 0.2,  1.9,  3.4, 11.8]),
#  'STL': array([0.3, 1.1, 1.6, 3.5]),
#  'BLK': array([0. , 0.5, 1.2, 5.8]),
#  'TOV': array([1. , 2.3, 3. , 5. ]),
#  'PF': array([1.4, 2.5, 3.2, 7.6]),
#  'PTS': array([ 9.9, 17.8, 21.1, 32.3]),
#  'ORtg': array([ 95.5, 113.4, 119.2, 139. ]),
#  'DRtg': array([ 78.1,  93.1,  99.6, 112.2]),
#  'PER': array([11.9, 21.9, 25.9, 36.2]),
#  'TS%': array([0.485, 0.555, 0.59 , 0.697]),
#  'eFG%': array([0.438, 0.513, 0.552, 0.664]),
#  '3PAr': array([0.   , 0.178, 0.362, 0.666]),
#  'FTr': array([0.18 , 0.362, 0.462, 0.908]),
#  'ORB%': array([ 0.5,  3.8,  9. , 20. ]),
#  'DRB%': array([ 7. , 13.2, 19.2, 33. ]),
#  'TRB%': array([ 4.2,  9. , 14.1, 25.6]),
#  'AST%': array([ 0.9, 10.5, 18.4, 50. ]),
#  'STL%': array([0.4, 1.7, 2.3, 5. ]),
#  'BLK%': array([ 0.1,  1.4,  3.4, 13.7]),
#  'TOV%': array([ 5.7, 12. , 14.7, 27.8]),
#  'AST:TOV': array([0.05882353, 0.79411765, 1.375     , 3.61904762]),
#  'Hght\n(inches)': array([69., 78., 81., 85.]),
#  'Weight': array([160., 205., 230., 279.]),
#  'RSCI Rank': array([  1.        ,  24.        ,  45.59668508, 251.        ]),
#  'Max Measured Wingspan (inches)': array([71.  , 81.25, 84.5 , 90.25]),
#  'Avg Measured Wingspan (inches': array([70.88, 80.58, 84.  , 90.25]),
#  'Difference': array([-2.25,  3.  ,  4.5 ,  8.25])}

# %%
clf.transform(X).head()
# Out:
#          Pk       Age       SOS        FG       FGA       FG%        2P  \
# 0 -0.202747 -0.012195 -0.012195 -0.030214  0.043894  0.181095  0.123937
# 1 -0.202747 -0.012195 -0.080858 -0.030214  0.043894 -0.553462 -0.072773
# 2 -0.202747 -0.117225 -0.080858 -0.145727 -0.247627 -0.553462 -0.054755
# 3 -0.202747  0.123937  0.086197 -0.145727 -0.247627 -0.553462 -0.054755
# 4  0.484950  0.123937 -0.012195 -0.145727 -0.247627  0.292560 -0.054755
#
#         2PA       2P%        3P  ...      STL%      BLK%      TOV%   AST:TOV  \
# 0  0.178997  0.292560 -0.127378  ... -0.163745 -0.030214 -0.117225 -0.247627
# 1  0.178997 -0.281528 -0.127378  ...  0.192930 -0.152316 -0.117225  0.200898
# 2 -0.017714 -0.281528 -0.117225  ... -0.163745 -0.152316 -0.198836 -0.247627
# 3 -0.017714 -0.281528 -0.127378  ... -0.070219 -0.152316  0.292560  0.200898
# 4 -0.017714 -0.036406 -0.117225  ... -0.070219 -0.152316 -0.117225 -0.247627
#
#    Hght\n(inches)    Weight  RSCI Rank  Max Measured Wingspan (inches)  \
# 0       -0.112452 -0.090473  -0.169411                       -0.115736
# 1       -0.112452 -0.090473  -0.169411                       -0.115736
# 2       -0.112452 -0.090473  -0.169411                       -0.115736
# 3       -0.112452 -0.090473  -0.045962                       -0.115736
# 4       -0.112452 -0.090473  -0.169411                       -0.115736
#
#    Avg Measured Wingspan (inches  Difference
# 0                      -0.264721    0.038415
# 1                      -0.264721    0.251770
# 2                      -0.264721    0.038415
# 3                      -0.264721    0.038415
# 4                      -0.264721    0.251770
#
# [5 rows x 43 columns]

# %%
from xverse.graph import BarCharts

# %%
woe_df = clf.woe_df

# %%
clf = BarCharts(bar_type='v')

# %%
clf.plot(woe_df)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:338: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /opt/anaconda3/lib/python3.7/site-packages/xverse/graph/_bivariate_charts.py:152: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
# BarCharts(bar_color='#058caa', bar_type='v', exclude_features=None,
#           feature_names='all', fig_size=(8, 6), num_color='#ed8549',
#           plot_metric='mean')

# %%
from xverse.ensemble import VotingSelector

clf = VotingSelector()
clf.fit(X, y)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# VotingSelector(exclude_features=None, feature_names='all',
#                handle_category='woe', minimum_votes=0, no_of_features=21,
#                numerical_missing_values='median',
#                selection_techniques=['WOE', 'RF', 'RFE', 'ETC', 'CS', 'L_ONE'])

# %%
clf.available_techniques
# Out:
# ['WOE', 'RF', 'RFE', 'ETC', 'CS', 'L_ONE']

# %%
clf.feature_importances_
# Out:
#                      Variable_Name  Information_Value  Random_Forest  \
# 0                               Pk           0.139634       0.020042
# 1                              FG%           0.132061       0.035206
# 2                              FTr           0.093228       0.016270
# 3                               FT           0.086998       0.028522
# 4                              PER           0.081987       0.034791
# 5                             DRtg           0.075157       0.015627
# 6                              FTA           0.067098       0.026857
# 7                              PTS           0.066017       0.025102
# 8                             DRB%           0.062726       0.020597
# 9                   Hght\n(inches)           0.057634       0.016214
# 10                             2P%           0.055748       0.032767
# 11                      Difference           0.047503       0.032043
# 12                            3PAr           0.047213       0.023247
# 13                            TOV%           0.047102       0.027729
# 14                             3PA           0.042530       0.028262
# 15                            AST%           0.041138       0.018673
# 16                             3P%           0.040305       0.023430
# 17   Avg Measured Wingspan (inches           0.034986       0.044582
# 18                             AST           0.034492       0.015849
# 19                             BLK           0.034254       0.014459
# 20                         AST:TOV           0.033319       0.020782
# 21                             TOV           0.032357       0.022039
# 22                             FGA           0.031364       0.039761
# 23                       RSCI Rank           0.029893       0.018192
# 24                            TRB%           0.026576       0.009827
# 25                              3P           0.026120       0.014460
# 26                            STL%           0.024092       0.022013
# 27  Max Measured Wingspan (inches)           0.023784       0.019295
# 28                             TRB           0.022785       0.024676
# 29                             2PA           0.022038       0.019739
# 30                            eFG%           0.021849       0.004515
# 31                          Weight           0.019664       0.016831
# 32                            BLK%           0.019059       0.019179
# 33                             STL           0.017804       0.007000
# 34                            ORB%           0.016577       0.015400
# 35                              FG           0.016028       0.022238
# 36                             TS%           0.014584       0.031261
# 37                              PF           0.014236       0.029954
# 38                             Age           0.009722       0.024037
# 39                              2P           0.007956       0.030144
# 40                             SOS           0.004701       0.020768
# 41                             FT%           0.002707       0.041218
# 42                            ORtg           0.002484       0.026402
#
#     Recursive_Feature_Elimination  Extra_Trees  Chi_Square     L_One
# 0                        0.000000     0.020786    0.030614 -0.001956
# 1                        0.000000     0.023417    0.135293  0.000000
# 2                        0.000000     0.023317    0.091268  0.000000
# 3                        0.004590     0.020220    0.255853  0.000000
# 4                        0.309530     0.038186    0.009212  0.000000
# 5                        0.000000     0.016091    0.046111 -0.002647
# 6                        0.000000     0.015143    0.296122  0.000000
# 7                       -0.570136     0.031091    0.163321 -0.011465
# 8                        0.000000     0.020247    0.125188  0.000000
# 9                        0.000000     0.022918    0.062922  0.000000
# 10                       0.000000     0.036138    0.212003  0.000000
# 11                       0.000000     0.031782    0.000522  0.000000
# 12                       0.169623     0.015883    0.118908  0.000000
# 13                       0.000000     0.020280    0.001505  0.000000
# 14                       0.157135     0.011172    0.332746  0.000000
# 15                       0.000000     0.027012    0.092779 -0.002279
# 16                      -0.340643     0.028994    0.165041  0.000000
# 17                       0.000000     0.031192    0.058920  0.000000
# 18                      -0.437394     0.024504    0.116211  0.000000
# 19                       0.000000     0.021085    0.025785  0.000000
# 20                       0.264640     0.026890    0.004536  0.000000
# 21                       0.415627     0.018933    0.162981  0.000000
# 22                       0.201879     0.025600    0.179278  0.000000
# 23                       0.000000     0.033210    0.116213  0.001618
# 24                      -0.187083     0.028939    0.084415  0.000000
# 25                      -0.370816     0.013323    0.411290  0.000000
# 26                      -0.206793     0.025797    0.208057  0.000000
# 27                       0.000000     0.017722    0.049766  0.000000
# 28                       0.269132     0.013938    0.068169  0.000000
# 29                      -0.190840     0.015870    0.003357  0.000000
# 30                       0.000000     0.016185    0.049116  0.000000
# 31                       0.000000     0.025608    0.059211  0.000498
# 32                      -0.253236     0.022057    0.021106  0.000000
# 33                      -0.339278     0.022506    0.282140  0.000000
# 34                      -0.234872     0.021935    0.021544  0.000000
# 35                       0.000000     0.024468    0.029313  0.000000
# 36                       0.000000     0.031662    0.022206  0.000000
# 37                       0.389737     0.030876    0.021689  0.000000
# 38                       0.000000     0.022956    0.005266  0.000000
# 39                       0.655050     0.022143    0.025437  0.000000
# 40                       0.000000     0.021406    0.003797  0.000000
# 41                       0.503741     0.020438    0.002459  0.000000
# 42                       0.000000     0.018082    0.005813  0.000000

# %%
clf.feature_votes_
# Out:
#                      Variable_Name  Information_Value  Random_Forest  \
# 7                              PTS                  1              1
# 16                             3P%                  1              1
# 12                            3PAr                  1              1
# 14                             3PA                  1              1
# 3                               FT                  1              1
# 4                              PER                  1              1
# 1                              FG%                  1              1
# 18                             AST                  1              0
# 10                             2P%                  1              1
# 22                             FGA                  0              1
# 17   Avg Measured Wingspan (inches                  1              1
# 15                            AST%                  1              0
# 11                      Difference                  1              1
# 9                   Hght\n(inches)                  1              0
# 6                              FTA                  1              1
# 2                              FTr                  1              0
# 26                            STL%                  0              0
# 13                            TOV%                  1              1
# 28                             TRB                  0              1
# 8                             DRB%                  1              0
# 37                              PF                  0              1
# 20                         AST:TOV                  1              0
# 23                       RSCI Rank                  0              0
# 24                            TRB%                  0              0
# 36                             TS%                  0              1
# 0                               Pk                  1              0
# 38                             Age                  0              1
# 39                              2P                  0              1
# 33                             STL                  0              0
# 41                             FT%                  0              1
# 35                              FG                  0              1
# 21                             TOV                  0              0
# 31                          Weight                  0              0
# 25                              3P                  0              0
# 5                             DRtg                  1              0
# 32                            BLK%                  0              0
# 34                            ORB%                  0              0
# 29                             2PA                  0              0
# 19                             BLK                  1              0
# 42                            ORtg                  0              1
# 30                            eFG%                  0              0
# 27  Max Measured Wingspan (inches)                  0              0
# 40                             SOS                  0              0
#
#     Recursive_Feature_Elimination  Extra_Trees  Chi_Square  L_One  Votes
# 7                               1            1           1      1      6
# 16                              1            1           1      1      6
# 12                              1            0           1      1      5
# 14                              1            0           1      1      5
# 3                               1            0           1      1      5
# 4                               1            1           0      1      5
# 1                               0            1           1      1      5
# 18                              1            1           1      1      5
# 10                              0            1           1      1      5
# 22                              1            1           1      0      4
# 17                              0            1           0      1      4
# 15                              0            1           1      1      4
# 11                              0            1           0      1      4
# 9                               0            1           1      1      4
# 6                               0            0           1      1      4
# 2                               0            1           1      1      4
# 26                              1            1           1      0      3
# 13                              0            0           0      1      3
# 28                              1            0           1      0      3
# 8                               0            0           1      1      3
# 37                              1            1           0      0      3
# 20                              1            1           0      0      3
# 23                              0            1           1      1      3
# 24                              1            1           1      0      3
# 36                              0            1           0      0      2
# 0                               0            0           0      1      2
# 38                              0            1           0      0      2
# 39                              1            0           0      0      2
# 33                              1            0           1      0      2
# 41                              1            0           0      0      2
# 35                              0            1           0      0      2
# 21                              1            0           1      0      2
# 31                              0            1           0      1      2
# 25                              1            0           1      0      2
# 5                               0            0           0      1      2
# 32                              1            0           0      0      1
# 34                              1            0           0      0      1
# 29                              1            0           0      0      1
# 19                              0            0           0      0      1
# 42                              0            0           0      0      1
# 30                              0            0           0      0      0
# 27                              0            0           0      0      0
# 40                              0            0           0      0      0

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
list(df.columns)
# Out:
# ['Player',
#  'Pk',
#  'Age',
#  'SOS',
#  'FG',
#  'FGA',
#  'FG%',
#  '2P',
#  '2PA',
#  '2P%',
#  '3P',
#  '3PA',
#  '3P%',
#  'FT',
#  'FTA',
#  'FT%',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS',
#  'ORtg',
#  'DRtg',
#  'PER',
#  'TS%',
#  'eFG%',
#  '3PAr',
#  'FTr',
#  'ORB%',
#  'DRB%',
#  'TRB%',
#  'AST%',
#  'STL%',
#  'BLK%',
#  'TOV%',
#  'AST:TOV',
#  'Hght\n(inches)',
#  'Weight',
#  'RSCI Rank',
#  'Max Measured Wingspan (inches)',
#  'Avg Measured Wingspan (inches',
#  'Difference',
#  'Bench']

# %%
features = ['SOS','FG','FGA','FG%', '2P','2PA','2P%','3P','3P%','FT','FTA','FT%','TRB','AST',
'STL','BLK','TOV','PF','PTS','ORtg','PER','TS%','eFG%','3PAr','FTr', 'ORB%','DRB%','TRB%','AST%',
 'BLK%','TOV%','AST:TOV','Hght\n(inches)','Weight','RSCI Rank', 'Max Measured Wingspan (inches)',
'Avg Measured Wingspan (inches', 'Difference']

# %%
import seaborn as sns

# %%
sns.pairplot(df[['FT','3PA', 'FG%','PER','AST%','PTS', '2P%','Bench']], hue='Bench',kind="scatter",plot_kws=dict(s=80, edgecolor="white", linewidth=2.5))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
import numpy as np

from sklearn.model_selection import StratifiedKFold
from yellowbrick.model_selection import LearningCurve

# Create the learning curve visualizer
cv = StratifiedKFold(n_splits=12)
sizes = np.linspace(0.3, 1.0, 10)

# Instantiate the classification model and visualizer
model = LogisticRegression(solver='liblinear', random_state=2)
visualizer = LearningCurve(
    model, cv=cv, scoring='roc_auc', train_sizes=sizes, n_jobs=4
)

visualizer.fit(X, y)        # Fit the data to the visualizer
visualizer.show()           # Finalize and render the figure
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/yellowbrick/base.py:246: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
from sklearn.model_selection import StratifiedKFold
from yellowbrick.model_selection import CVScores

# Create a cross-validation strategy
cv = StratifiedKFold(n_splits=12, random_state=42)

# Instantiate the classification model and visualizer
model = LogisticRegression(solver='liblinear', random_state=2)
visualizer = CVScores(model, cv=cv, scoring='roc_auc')

visualizer.fit(X, y)        # Fit the data to the visualizer
visualizer.show()           # Finalize and render the figure
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/yellowbrick/base.py:246: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
sns.pairplot(df[['FT','3PA', 'FG%','PER','AST%','PTS', '2P%','Bench']], hue='Bench',kind="scatter",plot_kws=dict(s=80, edgecolor="white", linewidth=2.5))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
X = df.drop(['Pk','SOS','FG','FGA','2P','2PA','3P','3P%','FT%','FTA','TRB', 'Player', 'Age',
 'STL','BLK','TOV','PF','ORtg','DRtg','TS%','eFG%','3PAr','Bench', 'FTr','DRB%','ORB%', 'TRB%',
 'AST','STL%','BLK%','TOV%','AST:TOV','Hght\n(inches)', 'Weight','RSCI Rank', 'Max Measured Wingspan (inches)',
 'Avg Measured Wingspan (inches','Difference'], axis=1)
y = df['Bench']

# %%
X
# Out:
#        FG%    2P%  3PA   FT   PTS   PER  AST%
# 0    0.529  0.569  5.1  8.4  25.3  32.5  29.8
# 1    0.423  0.461  6.8  4.0  19.3  19.3  23.4
# 2    0.428  0.471  5.9  6.7  25.0  29.9  28.0
# 3    0.452  0.491  9.5  7.6  32.3  30.9  28.8
# 4    0.458  0.501  5.2  5.9  24.3  25.7  30.3
# ..     ...    ...  ...  ...   ...   ...   ...
# 230  0.664  0.664  0.0  3.5  23.0  30.7   9.4
# 231  0.646  0.646  0.0  6.0  22.7  31.1  13.9
# 232  0.620  0.623  0.1  1.7  16.1  26.4  12.9
# 233  0.568  0.568  0.0  5.1  21.6  26.6   4.2
# 234  0.477  0.492  1.0  3.7  16.0  17.6   6.4
#
# [235 rows x 7 columns]

# %%
import numpy as np

from sklearn.model_selection import StratifiedKFold
from yellowbrick.model_selection import LearningCurve

# Create the learning curve visualizer
cv = StratifiedKFold(n_splits=12)
sizes = np.linspace(0.3, 1.0, 10)

# Instantiate the classification model and visualizer
model = LogisticRegression(solver='liblinear', random_state=2)
visualizer = LearningCurve(
    model, cv=cv, scoring='roc_auc', train_sizes=sizes, n_jobs=4
)

visualizer.fit(X, y)        # Fit the data to the visualizer
visualizer.show()           # Finalize and render the figure
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/yellowbrick/base.py:246: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
from sklearn.model_selection import StratifiedKFold
from yellowbrick.model_selection import CVScores

# Create a cross-validation strategy
cv = StratifiedKFold(n_splits=12, random_state=42)

# Instantiate the classification model and visualizer
model = LogisticRegression(solver='liblinear', random_state=2)
visualizer = CVScores(model, cv=cv, scoring='roc_auc')

visualizer.fit(X, y)        # Fit the data to the visualizer
visualizer.show()           # Finalize and render the figure
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/yellowbrick/base.py:246: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
X
# Out:
#        FG%    2P%  3PA   FT   PTS   PER  AST%
# 0    0.529  0.569  5.1  8.4  25.3  32.5  29.8
# 1    0.423  0.461  6.8  4.0  19.3  19.3  23.4
# 2    0.428  0.471  5.9  6.7  25.0  29.9  28.0
# 3    0.452  0.491  9.5  7.6  32.3  30.9  28.8
# 4    0.458  0.501  5.2  5.9  24.3  25.7  30.3
# ..     ...    ...  ...  ...   ...   ...   ...
# 230  0.664  0.664  0.0  3.5  23.0  30.7   9.4
# 231  0.646  0.646  0.0  6.0  22.7  31.1  13.9
# 232  0.620  0.623  0.1  1.7  16.1  26.4  12.9
# 233  0.568  0.568  0.0  5.1  21.6  26.6   4.2
# 234  0.477  0.492  1.0  3.7  16.0  17.6   6.4
#
# [235 rows x 7 columns]

# %%
features = ['FG%', '2P%', '3PA','FT','PTS','PER','AST%']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
logreg = LogisticRegression(solver='liblinear', random_state=2).fit(x_train, y_train)
y_scores_logreg = logreg.predict_proba(x_test)[:,1]
y_pred_logreg = logreg.predict(x_test)

print("Train accuracy:",logreg.score(x_train, y_train))
print("Test accuracy:", logreg.score(x_test, y_test))
print("ROC AUC:", roc_auc_score(y_test, y_scores_logreg))

ax = pd.DataFrame(
    logreg.coef_.transpose(),
    index=features,
    columns=['coefficients']
).sort_values('coefficients').plot(
    kind='barh', legend=False, title='Logistic Regression Feature Coefficients', figsize=(10,5), fontsize=14
)

ax.title.set_size(16)
# Out:
# Train accuracy: 0.7045454545454546
# Test accuracy: 0.6271186440677966
# ROC AUC: 0.5200501253132832

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

# %%
xg_cl = xgb.XGBClassifier()

# %%
params = {"max_depth": [10,30,50],
              "min_child_weight" : [1,3,6],
              "n_estimators": [200],
              "learning_rate": [0.05, 0.1,0.16],}

# %%
grid_search = GridSearchCV(xg_cl, params, cv = 3, verbose=10, n_jobs=-1)

# %%
grid_search.fit(X_train, Y_train)
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1980s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1138s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done  66 out of  81 | elapsed:    3.0s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  75 out of  81 | elapsed:    3.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  81 out of  81 | elapsed:    3.1s finished
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      colsample_bylevel=1, colsample_bynode=1,
#                                      colsample_bytree=1, gamma=0,
#                                      learning_rate=0.1, max_delta_step=0,
#                                      max_depth=3, min_child_weight=1,
#                                      missing=None, n_estimators=100, n_jobs=1,
#                                      nthread=None, objective='binary:logistic',
#                                      random_state=0, reg_alpha=0, reg_lambda=1,
#                                      scale_pos_weight=1, seed=None, silent=None,
#                                      subsample=1, verbosity=1),
#              iid='warn', n_jobs=-1,
#              param_grid={'learning_rate': [0.05, 0.1, 0.16],
#                          'max_depth': [10, 30, 50],
#                          'min_child_weight': [1, 3, 6], 'n_estimators': [200]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=10)

# %%
grid_search.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.05, max_delta_step=0, max_depth=10,
#               min_child_weight=6, missing=None, n_estimators=200, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score

# %%
xg = xgb.XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=1, gamma=0,
              learning_rate=0.05, max_delta_step=0, max_depth=10,
              min_child_weight=6, missing=None, n_estimators=200, n_jobs=1,
              nthread=None, objective='binary:logistic', random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
              silent=None, subsample=1, verbosity=1).fit(X_train, Y_train)
y_scores_xg = xg.predict_proba(X_test)[:,1]

print("Train Accuracy:",xg.score(X_train, Y_train))
print("Test Accuracy:", xg.score(X_test, Y_test))
print("ROC AUC:", roc_auc_score(Y_test, y_scores_xg))
# Out:
# Train Accuracy: 0.8409090909090909
# Test Accuracy: 0.6440677966101694
# ROC AUC: 0.6115288220551378

# %%
xg_roc_auc = roc_auc_score(Y_test, y_scores_xg)
fpr, tpr, thresholds = metrics.roc_curve(Y_test, y_scores_xg)
plt.plot(fpr, tpr, label='XGBoost (AUC = %0.2f)' % xg_roc_auc)
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Random Model', alpha=.8)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   if sys.path[0] == '':

# %%
import shap

# %%
explainer = shap.TreeExplainer(xg)

# %%
shap_values = explainer.shap_values(X_train)

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...

# %%
shap.summary_plot(shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/summary.py:464: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
shap.summary_plot(shap_values, X_train, plot_type="bar")

# %%
shap_interaction_values = shap.TreeExplainer(xg).shap_interaction_values(X)

# %%
shap.summary_plot(shap_interaction_values, X)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/summary.py:181: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
shap.dependence_plot('PER', shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/dependence.py:291: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
shap.dependence_plot("2P%", shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/dependence.py:291: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
shap.dependence_plot("3PA", shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/dependence.py:291: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
shap.dependence_plot("PTS", shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/dependence.py:291: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
shap.dependence_plot("FT", shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/dependence.py:291: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
shap.dependence_plot("FG%", shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/dependence.py:291: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
shap.dependence_plot("AST%", shap_values, X_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/shap/plots/dependence.py:291: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   pl.show()

# %%
dataset = pd.read_excel('2017 Complete Bench.xlsx')

# %%
players = dataset['Player']
dataset = dataset.drop('Player', axis=1)
predictions = xg.predict_proba(dataset)[:,1]
print(predictions)
# Out:
# [0.13492127 0.19964407 0.26449904 0.13715856 0.0752838  0.35327077
#  0.03133454 0.07799547 0.33015433 0.52645284 0.1831096  0.16162576
#  0.23094831 0.23636812 0.17764884 0.08722878 0.23565857 0.16206181
#  0.33214977 0.1756836  0.1048761  0.17446154 0.41179094 0.33606148
#  0.28103286 0.13004437 0.16438363 0.05203196 0.12924759 0.16272688
#  0.41786474 0.2603464  0.4300526  0.527903   0.535318   0.09976871
#  0.41856092 0.58057207 0.19484387 0.0615928  0.24130827 0.553021
#  0.16617735 0.58057207 0.10004777 0.46256536 0.35122314 0.56105804
#  0.22787735 0.72332656]

# %%
output = {'Player':players, 'Bench': predictions}
output = pd.DataFrame(output, columns = ['Player', 'Bench'])
print(output)
# Out:
#                  Player     Bench
# 0        Markelle Fultz  0.134921
# 1            Lonzo Ball  0.199644
# 2          De'Aaron Fox  0.264499
# 3          Dennis Smith  0.137159
# 4         Derrick White  0.075284
# 5         Frank Jackson  0.353271
# 6           Frank Mason  0.031335
# 7           Jawun Evans  0.077995
# 8          Monte Morris  0.330154
# 9         Edmond Sumner  0.526453
# 10  Nigel Williams-Goss  0.183110
# 11           Malik Monk  0.161626
# 12         Luke Kennard  0.230948
# 13     Donovan Mitchell  0.236368
# 14            Josh Hart  0.177649
# 15           Davon Reed  0.087229
# 16        Wesley Iwundu  0.235659
# 17         Dwayne Bacon  0.162062
# 18         Tyler Dorsey  0.332150
# 19       Damyean Dotson  0.175684
# 20       Sterling Brown  0.104876
# 21         Kadeem Allen  0.174462
# 22          Jabari Bird  0.411791
# 23         Jayson Tatum  0.336061
# 24         Josh Jackson  0.281033
# 25       Justin Jackson  0.130044
# 26           OG Anunoby  0.164384
# 27         Semi Ojeleye  0.052032
# 28        Dillon Brooks  0.129248
# 29  Sindarius Thornwell  0.162727
# 30    Jaron Blossomgame  0.417865
# 31       Jonathan Isaac  0.260346
# 32      Lauri Markkanen  0.430053
# 33          Bam Adebayo  0.527903
# 34          D.J. Wilson  0.535318
# 35            T.J. Leaf  0.099769
# 36         John Collins  0.418561
# 37          Harry Giles  0.580572
# 38          Tyler Lydon  0.194844
# 39       Caleb Swanigan  0.061593
# 40           Kyle Kuzma  0.241308
# 41            Ivan Rabb  0.553021
# 42          Jordan Bell  0.166177
# 43         Ike Anigbogu  0.580572
# 44          Alec Peters  0.100048
# 45         Zach Collins  0.462565
# 46        Justin Patton  0.351223
# 47        Jarrett Allen  0.561058
# 48         Tony Bradley  0.227877
# 49        Thomas Bryant  0.723327

# %%
output.to_excel("2017 Bench Prob Complete.xlsx")

# %%
dataset = pd.read_excel('2018 Complete Bench.xlsx')

# %%
players = dataset['Player']
dataset = dataset.drop('Player', axis=1)
predictions = xg.predict_proba(dataset)[:,1]
print(predictions)
# Out:
# [0.724421   0.49886674 0.17168544 0.11111643 0.10617672 0.11471454
#  0.12012165 0.08210262 0.20740156 0.2126414  0.4092223  0.13130772
#  0.2191212  0.21391241 0.6151388  0.61373067 0.09742928 0.08802649
#  0.3683588  0.03667981 0.11988176 0.54132295 0.10884045 0.17764884
#  0.26495105 0.51913166 0.24611051 0.17480579 0.20679867 0.2468204
#  0.49875933 0.193006   0.05762237 0.21520795 0.14978433 0.10329788
#  0.39734358 0.2852518  0.08116689 0.19793926]

# %%
output = {'Player':players, 'Bench': predictions}
output = pd.DataFrame(output, columns = ['Player', 'Bench'])
print(output)
# Out:
#                  Player     Bench
# 0         DeAndre Ayton  0.724421
# 1         Marvin Bagley  0.498867
# 2     Jaren Jackson Jr.  0.171685
# 3         Mohamed Bamba  0.111116
# 4        Michael Porter  0.106177
# 5        Wendell Carter  0.114715
# 6            Trae Young  0.120122
# 7         Collin Sexton  0.082103
# 8         Mikal Bridges  0.207402
# 9            Kevin Knox  0.212641
# 10  Shai Gilgeous-Al...  0.409222
# 11        Miles Bridges  0.131308
# 12      Robert Williams  0.219121
# 13         Zhaire Smith  0.213912
# 14        Landry Shamet  0.615139
# 15         Khyri Thomas  0.613731
# 16       Gary Trent Jr.  0.097429
# 17        Lonnie Walker  0.088026
# 18        Kevin Huerter  0.368359
# 19   Chandler Hutchison  0.036680
# 20           Troy Brown  0.119882
# 21     Donte DiVincenzo  0.541323
# 22       Omari Spellman  0.108840
# 23        Jalen Brunson  0.177649
# 24        Aaron Holiday  0.264951
# 25      Jerome Robinson  0.519132
# 26         Trevon Duval  0.246111
# 27          Josh Okogie  0.174806
# 28    De'Anthony Melton  0.206799
# 29     Keita Bates-Diop  0.246820
# 30       Melvin Frazier  0.498759
# 31         Shake Milton  0.193006
# 32          Jacob Evans  0.057622
# 33          Bruce Brown  0.215208
# 34        Alize Johnson  0.149784
# 35        Grayson Allen  0.103298
# 36         Jevon Carter  0.397344
# 37       Devonte Graham  0.285252
# 38         Kevin Hervey  0.081167
# 39       Hamidou Diallo  0.197939

# %%
output.to_excel("2018 Bench Prob Complete.xlsx")
